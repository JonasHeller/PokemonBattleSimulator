# %%
#THIS ONLY WORKS WHEN YOU ARE ONLINE


from playsound import playsound
from rdflib import Graph, RDF, Namespace, Literal, URIRef
from SPARQLWrapper import SPARQLWrapper, JSON
import pandas as pd
import urllib.parse


# sparql = SPARQLWrapper("http://dbpedia.org/sparql")
# sparql.setQuery("""

#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     SELECT ?label
#     WHERE { <http://dbpedia.org/resource/Amsterdam> rdfs:label ?label }
# """)
# sparql.setReturnFormat(JSON)
# results = sparql.query().convert()
# print(results)
# for result in results["results"]["bindings"]:
#     print(result["label"]["value"])

# This code accesses the DBPedia database, and returns the result of the specified SPARQL query (test it!)

# %%
pokemon = pd.read_csv("Pokemon.csv")
pokegraph = Graph()
DBR = Namespace('http://dbpedia.org/resource/')
DBO = Namespace('http://dbpedia.org/ontology/')
RDFS = Namespace('http://www.w3.org/2000/01/rdf-schema#')
DUL = Namespace('http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#')
POK = Namespace('http://www.example.org/pokemon/')
BIBO = Namespace('http://purl.org/ontology/bibo/')
OWL = Namespace("http://www.w3.org/2002/07/owl#")
FOAF = Namespace("http://xmlns.com/foaf/0.1/")
PEXT = Namespace("http://www.ontotext.com/proton/protonext#")

pokegraph.bind('foaf', FOAF)
pokegraph.bind('pok',POK)
pokegraph.bind('dbr',DBR)
pokegraph.bind('dbo',DBO)
pokegraph.bind('rdfs',RDFS)
pokegraph.bind('dul',DUL)
pokegraph.bind('bibo',BIBO)
pokegraph.bind('owl',OWL)
pokegraph.bind('pext',PEXT)

# %%
#define types

normal = "Normal"
fighting = "Fighting"
flying = "Flying"
poison = "Poison"
ground = "Ground"
rock = "Rock"
bug = "Bug"
ghost = "Ghost"
steel = "Steel"
fire = "Fire"
water = "Water"
grass = "Grass"
electric = "Electric"
psychic = "Psychic"
ice = "Ice"
dragon = "Dragon"
dark = "Dark"
fairy = "Fairy"

totallist = [normal, fighting, flying, poison, ground, rock, bug, ghost, steel, fire, water, grass,
             electric, psychic, ice, dragon, dark, fairy]

    

weak_dict = {normal:[rock,steel], 
            fighting:[flying,poison,bug,psychic,fairy],
            flying:[rock,steel,electric],
            poison:[poison,ground,rock,ghost],
            ground:[bug,grass],
            rock:[fighting,ground,steel],
            bug:[fighting,flying,poison,ghost,steel,fire,fairy],
            ghost:[dark],
            steel:[steel,fire,water],
            fire:[rock,fire,water,dragon],
            water:[water,grass,dragon],
            grass:[flying,poison,bug,steel,fire,grass,dragon],
            electric:[grass,electric,dragon],
            psychic:[steel,psychic],
            ice:[steel,fire,water,ice],
            dragon:[steel],
            dark:[fighting,dark,fairy],
            fairy:[poison,steel,fire]
            }


ineffective_dict = {normal:[ghost],
                   fighting:[ghost],
                   flying:[],
                   poison:[steel],
                   ground:[flying],
                   rock:[],
                   bug:[],
                   ghost:[normal],
                   steel:[poison],
                   fire:[],
                   water:[],
                   grass:[],
                   electric:[ground],
                   psychic:[dark],
                   ice:[],
                   dragon:[fairy],
                   dark:[],
                   fairy:[]}


strong_dict = {normal:[],
                 fighting:[normal,rock,steel,ice,dark],
                 flying:[fighting,bug,grass],
                 poison:[grass,fairy],
                 ground:[poison,rock,steel,fire,electric],
                 rock:[flying,bug,fire,ice],
                 bug:[grass,psychic,dark],
                 ghost:[ghost,psychic],
                 steel:[rock,ice,fairy],
                 fire:[bug,steel,grass,ice],
                 water:[ground,rock,fire],
                 grass:[ground,rock,water],
                 electric:[flying,water],
                 psychic:[fighting,poison],
                 ice:[flying,ground,grass,dragon],
                 dragon:[dragon],
                 dark:[ghost,psychic],
                 fairy:[fighting,dragon,dark]}

gen_list = ['Kanto', 'Johto', 'Hoenn', 'Sinnoh', 'Unova', 'Kalos']

trainer_dict = {'Ash': ['Pikachu', 'Charizard'], 'Brock' : ['Onix'],
                'Misty' : ['Togepi', 'Psyduck'], 'Gary' : ['Blastoise', 'Arcanine']}

pokeball_dict = {'Ash' : ['Pokéball', 'Greatball', 'Ultraball'], 'Brock' : ['Pokéball', 'Greatball'],
                 'Misty' : ['Pokéball'], 'Gary' : ['Greatball', 'Ultraball']}


neutral_dict = {typing: [x for x in totallist if x not in (weak_dict[typing] + strong_dict[typing]
                                                           + ineffective_dict[typing])] for typing in totallist}
    
neutral_dict
# Out:
# {'Bug': ['Normal',
#   'Ground',
#   'Rock',
#   'Bug',
#   'Water',
#   'Electric',
#   'Ice',
#   'Dragon'],
#  'Dark': ['Normal',
#   'Flying',
#   'Poison',
#   'Ground',
#   'Rock',
#   'Bug',
#   'Steel',
#   'Fire',
#   'Water',
#   'Grass',
#   'Electric',
#   'Ice',
#   'Dragon'],
#  'Dragon': ['Normal',
#   'Fighting',
#   'Flying',
#   'Poison',
#   'Ground',
#   'Rock',
#   'Bug',
#   'Ghost',
#   'Fire',
#   'Water',
#   'Grass',
#   'Electric',
#   'Psychic',
#   'Ice',
#   'Dark'],
#  'Electric': ['Normal',
#   'Fighting',
#   'Poison',
#   'Rock',
#   'Bug',
#   'Ghost',
#   'Steel',
#   'Fire',
#   'Psychic',
#   'Ice',
#   'Dark',
#   'Fairy'],
#  'Fairy': ['Normal',
#   'Flying',
#   'Ground',
#   'Rock',
#   'Bug',
#   'Ghost',
#   'Water',
#   'Grass',
#   'Electric',
#   'Psychic',
#   'Ice',
#   'Fairy'],
#  'Fighting': ['Fighting',
#   'Ground',
#   'Fire',
#   'Water',
#   'Grass',
#   'Electric',
#   'Dragon'],
#  'Fire': ['Normal',
#   'Fighting',
#   'Flying',
#   'Poison',
#   'Ground',
#   'Ghost',
#   'Electric',
#   'Psychic',
#   'Dark',
#   'Fairy'],
#  'Flying': ['Normal',
#   'Flying',
#   'Poison',
#   'Ground',
#   'Ghost',
#   'Fire',
#   'Water',
#   'Psychic',
#   'Ice',
#   'Dragon',
#   'Dark',
#   'Fairy'],
#  'Ghost': ['Fighting',
#   'Flying',
#   'Poison',
#   'Ground',
#   'Rock',
#   'Bug',
#   'Steel',
#   'Fire',
#   'Water',
#   'Grass',
#   'Electric',
#   'Ice',
#   'Dragon',
#   'Fairy'],
#  'Grass': ['Normal',
#   'Fighting',
#   'Ghost',
#   'Electric',
#   'Psychic',
#   'Ice',
#   'Dark',
#   'Fairy'],
#  'Ground': ['Normal',
#   'Fighting',
#   'Ground',
#   'Ghost',
#   'Water',
#   'Psychic',
#   'Ice',
#   'Dragon',
#   'Dark',
#   'Fairy'],
#  'Ice': ['Normal',
#   'Fighting',
#   'Poison',
#   'Rock',
#   'Bug',
#   'Ghost',
#   'Electric',
#   'Psychic',
#   'Dark',
#   'Fairy'],
#  'Normal': ['Normal',
#   'Fighting',
#   'Flying',
#   'Poison',
#   'Ground',
#   'Bug',
#   'Fire',
#   'Water',
#   'Grass',
#   'Electric',
#   'Psychic',
#   'Ice',
#   'Dragon',
#   'Dark',
#   'Fairy'],
#  'Poison': ['Normal',
#   'Fighting',
#   'Flying',
#   'Bug',
#   'Fire',
#   'Water',
#   'Electric',
#   'Psychic',
#   'Ice',
#   'Dragon',
#   'Dark'],
#  'Psychic': ['Normal',
#   'Flying',
#   'Ground',
#   'Rock',
#   'Bug',
#   'Ghost',
#   'Fire',
#   'Water',
#   'Grass',
#   'Electric',
#   'Ice',
#   'Dragon',
#   'Fairy'],
#  'Rock': ['Normal',
#   'Poison',
#   'Rock',
#   'Ghost',
#   'Water',
#   'Grass',
#   'Electric',
#   'Psychic',
#   'Dragon',
#   'Dark',
#   'Fairy'],
#  'Steel': ['Normal',
#   'Fighting',
#   'Flying',
#   'Ground',
#   'Bug',
#   'Ghost',
#   'Grass',
#   'Electric',
#   'Psychic',
#   'Dragon',
#   'Dark'],
#  'Water': ['Normal',
#   'Fighting',
#   'Flying',
#   'Poison',
#   'Bug',
#   'Ghost',
#   'Steel',
#   'Electric',
#   'Psychic',
#   'Ice',
#   'Dark',
#   'Fairy']}

# %%
#Add classes
pokegraph.add((POK.Pokémon, RDF.type, RDFS.Class))
pokegraph.add((POK.Region, RDF.type, RDFS.Class))
pokegraph.add((POK.Typing, RDF.type, RDFS.Class))
pokegraph.add((POK.FantasyWorld, RDF.type, RDFS.Class))
pokegraph.add((POK.PokémonWorld, RDF.type, RDFS.Class))
pokegraph.add((POK.Creature, RDF.type, RDFS.Class))
pokegraph.add((POK.Trainer, RDF.type, RDFS.Class))
pokegraph.add((POK.Item, RDF.type, RDFS.Class))
pokegraph.add((POK.Pokéball, RDF.type, RDFS.Class))
pokegraph.add((POK.Image, RDF.type, RDFS.Class))
pokegraph.add((POK.Sound, RDF.type, RDFS.Class))
pokegraph.add((PEXT.Human, RDF.type, RDFS.Class))
pokegraph.add((PEXT.Mammal, RDF.type, RDFS.Class))
pokegraph.add((POK.RealWorld, RDF.type, RDFS.Class))
pokegraph.add((POK.Media, RDF.type, RDFS.Class))

#Setup class hierarchy

pokegraph.add((POK.Media, RDFS.subClassOf, POK.RealWorld))
pokegraph.add((POK.Sound, RDFS.subClassOf, POK.Media))
pokegraph.add((POK.Image, RDFS.subClassOf, POK.Media))
pokegraph.add((POK.PokémonWorld, RDFS.subClassOf, POK.FantasyWorld))
pokegraph.add((POK.Creature, RDFS.subClassOf, POK.PokémonWorld))
pokegraph.add((PEXT.Mammal, RDFS.subClassOf, POK.Creature))
pokegraph.add((PEXT.Human, RDFS.subClassOf, PEXT.Mammal))
pokegraph.add((POK.Trainer, RDFS.subClassOf, PEXT.Human))
pokegraph.add((POK.Pokémon, RDFS.subClassOf, POK.Creature))
pokegraph.add((POK.Item, RDFS.subClassOf, POK.PokémonWorld))
pokegraph.add((POK.Pokéball, RDFS.subClassOf, POK.Item))
pokegraph.add((POK.Region, RDFS.subClassOf, POK.PokémonWorld))
pokegraph.add((POK.Typing, RDFS.subClassOf, POK.PokémonWorld))

#Load Pokémon info from csv and other places
for i in range(len(list(pokemon['Name']))):
    subject = URIRef("http://www.example.org/pokemon/" + pokemon['Name'][i].replace(' ', '_').replace('.', ''))
    
    
    #Load name, region and first type
    pokegraph.add((subject, FOAF.name, Literal(pokemon['Name'][i])))
    pokegraph.add((subject, POK.hasRegion, URIRef("http://www.example.org/pokemon/" + gen_list[int(pokemon['Generation'][i])-1])))
    pokegraph.add((subject, POK.hasType, URIRef("http://www.example.org/pokemon/" + pokemon['Type 1'][i])))
    
    
    #Load type 2 (optional since some Pokémon only have one type)
    if type(pokemon['Type 2'][i]) is not float:
        pokegraph.add((subject, POK.hasType, URIRef("http://www.example.org/pokemon/" + pokemon['Type 2'][i])))
        
        
    #Load Image
    ID = str(i+1)
    image = URIRef("https://pokeres.bastionbot.org/images/pokemon/" + ID + ".png")
    pokegraph.add((subject, BIBO.Image, image))
    
    #Load Sound
    if i < 9:
        encode = URIRef(urllib.parse.quote('sound/00' + str(i+1) + ' - ' + pokemon['Name'][i] + '.wav'))
        pokegraph.add((subject, BIBO.AudioDocument, encode))
    elif i < 99:
        encode = URIRef(urllib.parse.quote('sound/0' + str(i+1) + ' - ' + pokemon['Name'][i] + '.wav'))
        pokegraph.add((subject, BIBO.AudioDocument, encode))
    else:
        encode = URIRef(urllib.parse.quote('sound/' + str(i+1) + ' - ' + pokemon['Name'][i] + '.wav'))
        pokegraph.add((subject, BIBO.AudioDocument, encode))
        
#Load Trainer Pokéballs and Pokémon
for trainer in trainer_dict:
    trainerURI = URIRef("http://www.example.org/pokemon/" + trainer)
    
    for balltype in pokeball_dict[trainer]:
        pokeball = URIRef('http://www.example.org/pokemon/' + balltype)
        pokegraph.add((trainerURI, POK.hasItem, pokeball))
    
    for pok in trainer_dict[trainer]:
        subject = URIRef("http://www.example.org/pokemon/" + pok.replace(' ', '_').replace('.', ''))      
        pokegraph.add((trainerURI, POK.hasPokemon, subject))
        
#Load type advantages
for typing in totallist:
    typingURI = URIRef("http://www.example.org/pokemon/" + typing)
    
    for strong in strong_dict[typing]:
        pokegraph.add((typingURI, POK.StrongTo, URIRef("http://www.example.org/pokemon/" + strong)))
    for weak in weak_dict[typing]:
        pokegraph.add((typingURI, POK.WeakTo, URIRef("http://www.example.org/pokemon/" + weak)))
    for resist in ineffective_dict[typing]:
        pokegraph.add((typingURI, POK.WeakTo, URIRef("http://www.example.org/pokemon/" + resist)))
    for neutral in neutral_dict[typing]:
        pokegraph.add((typingURI, POK.NeutralTo, URIRef("http://www.example.org/pokemon/" + neutral)))
        
#playsound(urllib.parse.unquote(encode))
        
        
        
#Define object properties    
pokegraph.add((POK.hasType, RDF.type, OWL.ObjectProperty))    
pokegraph.add((POK.hasRegion, RDF.type, OWL.ObjectProperty))
pokegraph.add((FOAF.name, RDF.type, OWL.ObjectProperty))  
pokegraph.add((BIBO.Image, RDF.type, OWL.ObjectProperty))
pokegraph.add((BIBO.AudioDocument, RDF.type, OWL.ObjectProperty))
pokegraph.add((POK.hasPokemon, RDF.type, OWL.ObjectProperty))
pokegraph.add((POK.hasItem, RDF.type, OWL.ObjectProperty))

pokegraph.add((POK.StrongTo, RDF.type, OWL.ObjectProperty))
pokegraph.add((POK.WeakTo, RDF.type, OWL.ObjectProperty))
pokegraph.add((POK.NeutralTo, RDF.type, OWL.ObjectProperty))


#Define domains and ranges
pokegraph.add((POK.hasType, RDFS.domain, POK.Pokémon))
pokegraph.add((POK.hasType, RDFS.range, POK.Typing))
pokegraph.add((POK.hasRegion, RDFS.range, POK.Region))
pokegraph.add((BIBO.Image, RDFS.range, POK.Image))
pokegraph.add((BIBO.AudioDocument, RDFS.range, POK.Sound))
pokegraph.add((POK.hasPokemon, RDFS.domain, POK.Trainer))
pokegraph.add((POK.hasItem, RDFS.range, POK.Pokéball))


    
print(pokegraph.serialize(format='turtle').decode("utf-8"))
# Out:
# @prefix bibo: <http://purl.org/ontology/bibo/> .
# @prefix dbo: <http://dbpedia.org/ontology/> .
# @prefix dbr: <http://dbpedia.org/resource/> .
# @prefix dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#> .
# @prefix foaf: <http://xmlns.com/foaf/0.1/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix pext: <http://www.ontotext.com/proton/protonext#> .
# @prefix pok: <http://www.example.org/pokemon/> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xml: <http://www.w3.org/XML/1998/namespace> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# pok:Creature a rdfs:Class ;
#     rdfs:subClassOf pok:PokémonWorld .
#
# pok:FantasyWorld a rdfs:Class .
#
# pok:Image a rdfs:Class ;
#     rdfs:subClassOf pok:Media .
#
# pok:Item a rdfs:Class ;
#     rdfs:subClassOf pok:PokémonWorld .
#
# pok:Media a rdfs:Class ;
#     rdfs:subClassOf pok:RealWorld .
#
# pok:Pokéball a rdfs:Class ;
#     rdfs:subClassOf pok:Item .
#
# pok:Pokémon a rdfs:Class ;
#     rdfs:subClassOf pok:Creature .
#
# pok:PokémonWorld a rdfs:Class ;
#     rdfs:subClassOf pok:FantasyWorld .
#
# pok:RealWorld a rdfs:Class .
#
# pok:Region a rdfs:Class ;
#     rdfs:subClassOf pok:PokémonWorld .
#
# pok:Sound a rdfs:Class ;
#     rdfs:subClassOf pok:Media .
#
# pok:Trainer a rdfs:Class ;
#     rdfs:subClassOf pext:Human .
#
# pok:Typing a rdfs:Class ;
#     rdfs:subClassOf pok:PokémonWorld .
#
# pext:Human a rdfs:Class ;
#     rdfs:subClassOf pext:Mammal .
#
# pext:Mammal a rdfs:Class ;
#     rdfs:subClassOf pok:Creature .
#
# bibo:AudioDocument a owl:ObjectProperty ;
#     rdfs:range pok:Sound .
#
# bibo:Image a owl:ObjectProperty ;
#     rdfs:range pok:Image .
#
# pok:Abomasnow bibo:AudioDocument <sound/460%20-%20Abomasnow.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/460.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Grass,
#         pok:Ice ;
#     foaf:name "Abomasnow" .
#
# pok:Abra bibo:AudioDocument <sound/063%20-%20Abra.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/63.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Psychic ;
#     foaf:name "Abra" .
#
# pok:Absol bibo:AudioDocument <sound/359%20-%20Absol.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/359.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Dark ;
#     foaf:name "Absol" .
#
# pok:Accelgor bibo:AudioDocument <sound/617%20-%20Accelgor.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/617.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Bug ;
#     foaf:name "Accelgor" .
#
# pok:Aegislash bibo:AudioDocument <sound/681%20-%20Aegislash.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/681.png> ;
#     pok:hasRegion pok:Kalos ;
#     pok:hasType pok:Ghost,
#         pok:Steel ;
#     foaf:name "Aegislash" .
#
# pok:Aerodactyl bibo:AudioDocument <sound/142%20-%20Aerodactyl.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/142.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Flying,
#         pok:Rock ;
#     foaf:name "Aerodactyl" .
#
# pok:Aggron bibo:AudioDocument <sound/306%20-%20Aggron.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/306.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Rock,
#         pok:Steel ;
#     foaf:name "Aggron" .
#
# pok:Aipom bibo:AudioDocument <sound/190%20-%20Aipom.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/190.png> ;
#     pok:hasRegion pok:Johto ;
#     pok:hasType pok:Normal ;
#     foaf:name "Aipom" .
#
# pok:Alakazam bibo:AudioDocument <sound/065%20-%20Alakazam.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/65.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Psychic ;
#     foaf:name "Alakazam" .
#
# pok:Alomomola bibo:AudioDocument <sound/594%20-%20Alomomola.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/594.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Water ;
#     foaf:name "Alomomola" .
#
# pok:Altaria bibo:AudioDocument <sound/334%20-%20Altaria.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/334.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Dragon,
#         pok:Flying ;
#     foaf:name "Altaria" .
#
# pok:Amaura bibo:AudioDocument <sound/698%20-%20Amaura.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/698.png> ;
#     pok:hasRegion pok:Kalos ;
#     pok:hasType pok:Ice,
#         pok:Rock ;
#     foaf:name "Amaura" .
#
# pok:Ambipom bibo:AudioDocument <sound/424%20-%20Ambipom.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/424.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Normal ;
#     foaf:name "Ambipom" .
#
# pok:Amoonguss bibo:AudioDocument <sound/591%20-%20Amoonguss.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/591.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Grass,
#         pok:Poison ;
#     foaf:name "Amoonguss" .
#
# pok:Ampharos bibo:AudioDocument <sound/181%20-%20Ampharos.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/181.png> ;
#     pok:hasRegion pok:Johto ;
#     pok:hasType pok:Electric ;
#     foaf:name "Ampharos" .
#
# pok:Anorith bibo:AudioDocument <sound/347%20-%20Anorith.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/347.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Bug,
#         pok:Rock ;
#     foaf:name "Anorith" .
#
# pok:Arbok bibo:AudioDocument <sound/024%20-%20Arbok.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/24.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Poison ;
#     foaf:name "Arbok" .
#
# pok:Arceus bibo:AudioDocument <sound/493%20-%20Arceus.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/493.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Normal ;
#     foaf:name "Arceus" .
#
# pok:Archen bibo:AudioDocument <sound/566%20-%20Archen.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/566.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Flying,
#         pok:Rock ;
#     foaf:name "Archen" .
#
# pok:Archeops bibo:AudioDocument <sound/567%20-%20Archeops.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/567.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Flying,
#         pok:Rock ;
#     foaf:name "Archeops" .
#
# pok:Ariados bibo:AudioDocument <sound/168%20-%20Ariados.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/168.png> ;
#     pok:hasRegion pok:Johto ;
#     pok:hasType pok:Bug,
#         pok:Poison ;
#     foaf:name "Ariados" .
#
# pok:Armaldo bibo:AudioDocument <sound/348%20-%20Armaldo.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/348.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Bug,
#         pok:Rock ;
#     foaf:name "Armaldo" .
#
# pok:Aromatisse bibo:AudioDocument <sound/683%20-%20Aromatisse.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/683.png> ;
#     pok:hasRegion pok:Kalos ;
#     pok:hasType pok:Fairy ;
#     foaf:name "Aromatisse" .
#
# pok:Aron bibo:AudioDocument <sound/304%20-%20Aron.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/304.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Rock,
#         pok:Steel ;
#     foaf:name "Aron" .
#
# pok:Articuno bibo:AudioDocument <sound/144%20-%20Articuno.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/144.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Flying,
#         pok:Ice ;
#     foaf:name "Articuno" .
#
# pok:Ash pok:hasItem pok:Greatball,
#         pok:Pokéball,
#         pok:Ultraball ;
#     pok:hasPokemon pok:Charizard,
#         pok:Pikachu .
#
# pok:Audino bibo:AudioDocument <sound/531%20-%20Audino.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/531.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Normal ;
#     foaf:name "Audino" .
#
# pok:Aurorus bibo:AudioDocument <sound/699%20-%20Aurorus.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/699.png> ;
#     pok:hasRegion pok:Kalos ;
#     pok:hasType pok:Ice,
#         pok:Rock ;
#     foaf:name "Aurorus" .
#
# pok:Avalugg bibo:AudioDocument <sound/713%20-%20Avalugg.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/713.png> ;
#     pok:hasRegion pok:Kalos ;
#     pok:hasType pok:Ice ;
#     foaf:name "Avalugg" .
#
# pok:Axew bibo:AudioDocument <sound/610%20-%20Axew.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/610.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Dragon ;
#     foaf:name "Axew" .
#
# pok:Azelf bibo:AudioDocument <sound/482%20-%20Azelf.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/482.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Psychic ;
#     foaf:name "Azelf" .
#
# pok:Azumarill bibo:AudioDocument <sound/184%20-%20Azumarill.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/184.png> ;
#     pok:hasRegion pok:Johto ;
#     pok:hasType pok:Fairy,
#         pok:Water ;
#     foaf:name "Azumarill" .
#
# pok:Azurill bibo:AudioDocument <sound/298%20-%20Azurill.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/298.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Fairy,
#         pok:Normal ;
#     foaf:name "Azurill" .
#
# pok:Bagon bibo:AudioDocument <sound/371%20-%20Bagon.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/371.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Dragon ;
#     foaf:name "Bagon" .
#
# pok:Baltoy bibo:AudioDocument <sound/343%20-%20Baltoy.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/343.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Ground,
#         pok:Psychic ;
#     foaf:name "Baltoy" .
#
# pok:Banette bibo:AudioDocument <sound/354%20-%20Banette.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/354.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Ghost ;
#     foaf:name "Banette" .
#
# pok:Barbaracle bibo:AudioDocument <sound/689%20-%20Barbaracle.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/689.png> ;
#     pok:hasRegion pok:Kalos ;
#     pok:hasType pok:Rock,
#         pok:Water ;
#     foaf:name "Barbaracle" .
#
# pok:Barboach bibo:AudioDocument <sound/339%20-%20Barboach.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/339.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Ground,
#         pok:Water ;
#     foaf:name "Barboach" .
#
# pok:Basculin bibo:AudioDocument <sound/550%20-%20Basculin.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/550.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Water ;
#     foaf:name "Basculin" .
#
# pok:Bastiodon bibo:AudioDocument <sound/411%20-%20Bastiodon.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/411.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Rock,
#         pok:Steel ;
#     foaf:name "Bastiodon" .
#
# pok:Bayleef bibo:AudioDocument <sound/153%20-%20Bayleef.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/153.png> ;
#     pok:hasRegion pok:Johto ;
#     pok:hasType pok:Grass ;
#     foaf:name "Bayleef" .
#
# pok:Beartic bibo:AudioDocument <sound/614%20-%20Beartic.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/614.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Ice ;
#     foaf:name "Beartic" .
#
# pok:Beautifly bibo:AudioDocument <sound/267%20-%20Beautifly.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/267.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Bug,
#         pok:Flying ;
#     foaf:name "Beautifly" .
#
# pok:Beedrill bibo:AudioDocument <sound/015%20-%20Beedrill.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/15.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Bug,
#         pok:Poison ;
#     foaf:name "Beedrill" .
#
# pok:Beheeyem bibo:AudioDocument <sound/606%20-%20Beheeyem.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/606.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Psychic ;
#     foaf:name "Beheeyem" .
#
# pok:Beldum bibo:AudioDocument <sound/374%20-%20Beldum.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/374.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Psychic,
#         pok:Steel ;
#     foaf:name "Beldum" .
#
# pok:Bellossom bibo:AudioDocument <sound/182%20-%20Bellossom.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/182.png> ;
#     pok:hasRegion pok:Johto ;
#     pok:hasType pok:Grass ;
#     foaf:name "Bellossom" .
#
# pok:Bellsprout bibo:AudioDocument <sound/069%20-%20Bellsprout.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/69.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Grass,
#         pok:Poison ;
#     foaf:name "Bellsprout" .
#
# pok:Bergmite bibo:AudioDocument <sound/712%20-%20Bergmite.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/712.png> ;
#     pok:hasRegion pok:Kalos ;
#     pok:hasType pok:Ice ;
#     foaf:name "Bergmite" .
#
# pok:Bibarel bibo:AudioDocument <sound/400%20-%20Bibarel.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/400.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Normal,
#         pok:Water ;
#     foaf:name "Bibarel" .
#
# pok:Bidoof bibo:AudioDocument <sound/399%20-%20Bidoof.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/399.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Normal ;
#     foaf:name "Bidoof" .
#
# pok:Binacle bibo:AudioDocument <sound/688%20-%20Binacle.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/688.png> ;
#     pok:hasRegion pok:Kalos ;
#     pok:hasType pok:Rock,
#         pok:Water ;
#     foaf:name "Binacle" .
#
# pok:Bisharp bibo:AudioDocument <sound/625%20-%20Bisharp.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/625.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Dark,
#         pok:Steel ;
#     foaf:name "Bisharp" .
#
# pok:Blaziken bibo:AudioDocument <sound/257%20-%20Blaziken.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/257.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Fighting,
#         pok:Fire ;
#     foaf:name "Blaziken" .
#
# pok:Blissey bibo:AudioDocument <sound/242%20-%20Blissey.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/242.png> ;
#     pok:hasRegion pok:Johto ;
#     pok:hasType pok:Normal ;
#     foaf:name "Blissey" .
#
# pok:Blitzle bibo:AudioDocument <sound/522%20-%20Blitzle.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/522.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Electric ;
#     foaf:name "Blitzle" .
#
# pok:Boldore bibo:AudioDocument <sound/525%20-%20Boldore.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/525.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Rock ;
#     foaf:name "Boldore" .
#
# pok:Bonsly bibo:AudioDocument <sound/438%20-%20Bonsly.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/438.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Rock ;
#     foaf:name "Bonsly" .
#
# pok:Bouffalant bibo:AudioDocument <sound/626%20-%20Bouffalant.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/626.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Normal ;
#     foaf:name "Bouffalant" .
#
# pok:Braixen bibo:AudioDocument <sound/654%20-%20Braixen.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/654.png> ;
#     pok:hasRegion pok:Kalos ;
#     pok:hasType pok:Fire ;
#     foaf:name "Braixen" .
#
# pok:Braviary bibo:AudioDocument <sound/628%20-%20Braviary.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/628.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Flying,
#         pok:Normal ;
#     foaf:name "Braviary" .
#
# pok:Breloom bibo:AudioDocument <sound/286%20-%20Breloom.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/286.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Fighting,
#         pok:Grass ;
#     foaf:name "Breloom" .
#
# pok:Brock pok:hasItem pok:Greatball,
#         pok:Pokéball ;
#     pok:hasPokemon pok:Onix .
#
# pok:Bronzong bibo:AudioDocument <sound/437%20-%20Bronzong.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/437.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Psychic,
#         pok:Steel ;
#     foaf:name "Bronzong" .
#
# pok:Bronzor bibo:AudioDocument <sound/436%20-%20Bronzor.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/436.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Psychic,
#         pok:Steel ;
#     foaf:name "Bronzor" .
#
# pok:Budew bibo:AudioDocument <sound/406%20-%20Budew.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/406.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Grass,
#         pok:Poison ;
#     foaf:name "Budew" .
#
# pok:Buizel bibo:AudioDocument <sound/418%20-%20Buizel.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/418.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Water ;
#     foaf:name "Buizel" .
#
# pok:Bulbasaur bibo:AudioDocument <sound/001%20-%20Bulbasaur.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/1.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Grass,
#         pok:Poison ;
#     foaf:name "Bulbasaur" .
#
# pok:Buneary bibo:AudioDocument <sound/427%20-%20Buneary.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/427.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Normal ;
#     foaf:name "Buneary" .
#
# pok:Bunnelby bibo:AudioDocument <sound/659%20-%20Bunnelby.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/659.png> ;
#     pok:hasRegion pok:Kalos ;
#     pok:hasType pok:Normal ;
#     foaf:name "Bunnelby" .
#
# pok:Burmy bibo:AudioDocument <sound/412%20-%20Burmy.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/412.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Bug ;
#     foaf:name "Burmy" .
#
# pok:Butterfree bibo:AudioDocument <sound/012%20-%20Butterfree.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/12.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Bug,
#         pok:Flying ;
#     foaf:name "Butterfree" .
#
# pok:Cacnea bibo:AudioDocument <sound/331%20-%20Cacnea.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/331.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Grass ;
#     foaf:name "Cacnea" .
#
# pok:Cacturne bibo:AudioDocument <sound/332%20-%20Cacturne.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/332.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Dark,
#         pok:Grass ;
#     foaf:name "Cacturne" .
#
# pok:Camerupt bibo:AudioDocument <sound/323%20-%20Camerupt.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/323.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Fire,
#         pok:Ground ;
#     foaf:name "Camerupt" .
#
# pok:Carbink bibo:AudioDocument <sound/703%20-%20Carbink.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/703.png> ;
#     pok:hasRegion pok:Kalos ;
#     pok:hasType pok:Fairy,
#         pok:Rock ;
#     foaf:name "Carbink" .
#
# pok:Carnivine bibo:AudioDocument <sound/455%20-%20Carnivine.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/455.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Grass ;
#     foaf:name "Carnivine" .
#
# pok:Carracosta bibo:AudioDocument <sound/565%20-%20Carracosta.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/565.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Rock,
#         pok:Water ;
#     foaf:name "Carracosta" .
#
# pok:Carvanha bibo:AudioDocument <sound/318%20-%20Carvanha.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/318.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Dark,
#         pok:Water ;
#     foaf:name "Carvanha" .
#
# pok:Cascoon bibo:AudioDocument <sound/268%20-%20Cascoon.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/268.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Bug ;
#     foaf:name "Cascoon" .
#
# pok:Castform bibo:AudioDocument <sound/351%20-%20Castform.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/351.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Normal ;
#     foaf:name "Castform" .
#
# pok:Caterpie bibo:AudioDocument <sound/010%20-%20Caterpie.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/10.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Bug ;
#     foaf:name "Caterpie" .
#
# pok:Celebi bibo:AudioDocument <sound/251%20-%20Celebi.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/251.png> ;
#     pok:hasRegion pok:Johto ;
#     pok:hasType pok:Grass,
#         pok:Psychic ;
#     foaf:name "Celebi" .
#
# pok:Chandelure bibo:AudioDocument <sound/609%20-%20Chandelure.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/609.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Fire,
#         pok:Ghost ;
#     foaf:name "Chandelure" .
#
# pok:Chansey bibo:AudioDocument <sound/113%20-%20Chansey.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/113.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Normal ;
#     foaf:name "Chansey" .
#
# pok:Charmander bibo:AudioDocument <sound/004%20-%20Charmander.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/4.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Fire ;
#     foaf:name "Charmander" .
#
# pok:Charmeleon bibo:AudioDocument <sound/005%20-%20Charmeleon.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/5.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Fire ;
#     foaf:name "Charmeleon" .
#
# pok:Chatot bibo:AudioDocument <sound/441%20-%20Chatot.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/441.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Flying,
#         pok:Normal ;
#     foaf:name "Chatot" .
#
# pok:Cherrim bibo:AudioDocument <sound/421%20-%20Cherrim.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/421.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Grass ;
#     foaf:name "Cherrim" .
#
# pok:Cherubi bibo:AudioDocument <sound/420%20-%20Cherubi.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/420.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Grass ;
#     foaf:name "Cherubi" .
#
# pok:Chesnaught bibo:AudioDocument <sound/652%20-%20Chesnaught.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/652.png> ;
#     pok:hasRegion pok:Kalos ;
#     pok:hasType pok:Fighting,
#         pok:Grass ;
#     foaf:name "Chesnaught" .
#
# pok:Chespin bibo:AudioDocument <sound/650%20-%20Chespin.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/650.png> ;
#     pok:hasRegion pok:Kalos ;
#     pok:hasType pok:Grass ;
#     foaf:name "Chespin" .
#
# pok:Chikorita bibo:AudioDocument <sound/152%20-%20Chikorita.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/152.png> ;
#     pok:hasRegion pok:Johto ;
#     pok:hasType pok:Grass ;
#     foaf:name "Chikorita" .
#
# pok:Chimchar bibo:AudioDocument <sound/390%20-%20Chimchar.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/390.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Fire ;
#     foaf:name "Chimchar" .
#
# pok:Chimecho bibo:AudioDocument <sound/358%20-%20Chimecho.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/358.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Psychic ;
#     foaf:name "Chimecho" .
#
# pok:Chinchou bibo:AudioDocument <sound/170%20-%20Chinchou.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/170.png> ;
#     pok:hasRegion pok:Johto ;
#     pok:hasType pok:Electric,
#         pok:Water ;
#     foaf:name "Chinchou" .
#
# pok:Chingling bibo:AudioDocument <sound/433%20-%20Chingling.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/433.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Psychic ;
#     foaf:name "Chingling" .
#
# pok:Cinccino bibo:AudioDocument <sound/573%20-%20Cinccino.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/573.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Normal ;
#     foaf:name "Cinccino" .
#
# pok:Clamperl bibo:AudioDocument <sound/366%20-%20Clamperl.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/366.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Water ;
#     foaf:name "Clamperl" .
#
# pok:Clauncher bibo:AudioDocument <sound/692%20-%20Clauncher.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/692.png> ;
#     pok:hasRegion pok:Kalos ;
#     pok:hasType pok:Water ;
#     foaf:name "Clauncher" .
#
# pok:Clawitzer bibo:AudioDocument <sound/693%20-%20Clawitzer.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/693.png> ;
#     pok:hasRegion pok:Kalos ;
#     pok:hasType pok:Water ;
#     foaf:name "Clawitzer" .
#
# pok:Claydol bibo:AudioDocument <sound/344%20-%20Claydol.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/344.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Ground,
#         pok:Psychic ;
#     foaf:name "Claydol" .
#
# pok:Clefable bibo:AudioDocument <sound/036%20-%20Clefable.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/36.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Fairy ;
#     foaf:name "Clefable" .
#
# pok:Clefairy bibo:AudioDocument <sound/035%20-%20Clefairy.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/35.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Fairy ;
#     foaf:name "Clefairy" .
#
# pok:Cleffa bibo:AudioDocument <sound/173%20-%20Cleffa.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/173.png> ;
#     pok:hasRegion pok:Johto ;
#     pok:hasType pok:Fairy ;
#     foaf:name "Cleffa" .
#
# pok:Cloyster bibo:AudioDocument <sound/091%20-%20Cloyster.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/91.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Ice,
#         pok:Water ;
#     foaf:name "Cloyster" .
#
# pok:Cobalion bibo:AudioDocument <sound/638%20-%20Cobalion.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/638.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Fighting,
#         pok:Steel ;
#     foaf:name "Cobalion" .
#
# pok:Cofagrigus bibo:AudioDocument <sound/563%20-%20Cofagrigus.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/563.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Ghost ;
#     foaf:name "Cofagrigus" .
#
# pok:Combee bibo:AudioDocument <sound/415%20-%20Combee.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/415.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Bug,
#         pok:Flying ;
#     foaf:name "Combee" .
#
# pok:Combusken bibo:AudioDocument <sound/256%20-%20Combusken.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/256.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Fighting,
#         pok:Fire ;
#     foaf:name "Combusken" .
#
# pok:Conkeldurr bibo:AudioDocument <sound/534%20-%20Conkeldurr.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/534.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Fighting ;
#     foaf:name "Conkeldurr" .
#
# pok:Corphish bibo:AudioDocument <sound/341%20-%20Corphish.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/341.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Water ;
#     foaf:name "Corphish" .
#
# pok:Corsola bibo:AudioDocument <sound/222%20-%20Corsola.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/222.png> ;
#     pok:hasRegion pok:Johto ;
#     pok:hasType pok:Rock,
#         pok:Water ;
#     foaf:name "Corsola" .
#
# pok:Cottonee bibo:AudioDocument <sound/546%20-%20Cottonee.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/546.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Fairy,
#         pok:Grass ;
#     foaf:name "Cottonee" .
#
# pok:Cradily bibo:AudioDocument <sound/346%20-%20Cradily.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/346.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Grass,
#         pok:Rock ;
#     foaf:name "Cradily" .
#
# pok:Cranidos bibo:AudioDocument <sound/408%20-%20Cranidos.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/408.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Rock ;
#     foaf:name "Cranidos" .
#
# pok:Crawdaunt bibo:AudioDocument <sound/342%20-%20Crawdaunt.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/342.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Dark,
#         pok:Water ;
#     foaf:name "Crawdaunt" .
#
# pok:Cresselia bibo:AudioDocument <sound/488%20-%20Cresselia.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/488.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Psychic ;
#     foaf:name "Cresselia" .
#
# pok:Croagunk bibo:AudioDocument <sound/453%20-%20Croagunk.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/453.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Fighting,
#         pok:Poison ;
#     foaf:name "Croagunk" .
#
# pok:Crobat bibo:AudioDocument <sound/169%20-%20Crobat.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/169.png> ;
#     pok:hasRegion pok:Johto ;
#     pok:hasType pok:Flying,
#         pok:Poison ;
#     foaf:name "Crobat" .
#
# pok:Croconaw bibo:AudioDocument <sound/159%20-%20Croconaw.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/159.png> ;
#     pok:hasRegion pok:Johto ;
#     pok:hasType pok:Water ;
#     foaf:name "Croconaw" .
#
# pok:Crustle bibo:AudioDocument <sound/558%20-%20Crustle.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/558.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Bug,
#         pok:Rock ;
#     foaf:name "Crustle" .
#
# pok:Cryogonal bibo:AudioDocument <sound/615%20-%20Cryogonal.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/615.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Ice ;
#     foaf:name "Cryogonal" .
#
# pok:Cubchoo bibo:AudioDocument <sound/613%20-%20Cubchoo.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/613.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Ice ;
#     foaf:name "Cubchoo" .
#
# pok:Cubone bibo:AudioDocument <sound/104%20-%20Cubone.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/104.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Ground ;
#     foaf:name "Cubone" .
#
# pok:Cyndaquil bibo:AudioDocument <sound/155%20-%20Cyndaquil.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/155.png> ;
#     pok:hasRegion pok:Johto ;
#     pok:hasType pok:Fire ;
#     foaf:name "Cyndaquil" .
#
# pok:Darkrai bibo:AudioDocument <sound/491%20-%20Darkrai.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/491.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Dark ;
#     foaf:name "Darkrai" .
#
# pok:DarmanitanStandard_Mode bibo:AudioDocument <sound/555%20-%20DarmanitanStandard%20Mode.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/555.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Fire ;
#     foaf:name "DarmanitanStandard Mode" .
#
# pok:Darumaka bibo:AudioDocument <sound/554%20-%20Darumaka.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/554.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Fire ;
#     foaf:name "Darumaka" .
#
# pok:Dedenne bibo:AudioDocument <sound/702%20-%20Dedenne.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/702.png> ;
#     pok:hasRegion pok:Kalos ;
#     pok:hasType pok:Electric,
#         pok:Fairy ;
#     foaf:name "Dedenne" .
#
# pok:Deerling bibo:AudioDocument <sound/585%20-%20Deerling.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/585.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Grass,
#         pok:Normal ;
#     foaf:name "Deerling" .
#
# pok:Deino bibo:AudioDocument <sound/633%20-%20Deino.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/633.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Dark,
#         pok:Dragon ;
#     foaf:name "Deino" .
#
# pok:Delcatty bibo:AudioDocument <sound/301%20-%20Delcatty.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/301.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Normal ;
#     foaf:name "Delcatty" .
#
# pok:Delibird bibo:AudioDocument <sound/225%20-%20Delibird.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/225.png> ;
#     pok:hasRegion pok:Johto ;
#     pok:hasType pok:Flying,
#         pok:Ice ;
#     foaf:name "Delibird" .
#
# pok:Delphox bibo:AudioDocument <sound/655%20-%20Delphox.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/655.png> ;
#     pok:hasRegion pok:Kalos ;
#     pok:hasType pok:Fire,
#         pok:Psychic ;
#     foaf:name "Delphox" .
#
# pok:Deoxys bibo:AudioDocument <sound/386%20-%20Deoxys.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/386.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Psychic ;
#     foaf:name "Deoxys" .
#
# pok:Dewgong bibo:AudioDocument <sound/087%20-%20Dewgong.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/87.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Ice,
#         pok:Water ;
#     foaf:name "Dewgong" .
#
# pok:Dewott bibo:AudioDocument <sound/502%20-%20Dewott.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/502.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Water ;
#     foaf:name "Dewott" .
#
# pok:Dialga bibo:AudioDocument <sound/483%20-%20Dialga.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/483.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Dragon,
#         pok:Steel ;
#     foaf:name "Dialga" .
#
# pok:Diancie bibo:AudioDocument <sound/719%20-%20Diancie.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/719.png> ;
#     pok:hasRegion pok:Kalos ;
#     pok:hasType pok:Fairy,
#         pok:Rock ;
#     foaf:name "Diancie" .
#
# pok:Diggersby bibo:AudioDocument <sound/660%20-%20Diggersby.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/660.png> ;
#     pok:hasRegion pok:Kalos ;
#     pok:hasType pok:Ground,
#         pok:Normal ;
#     foaf:name "Diggersby" .
#
# pok:Diglett bibo:AudioDocument <sound/050%20-%20Diglett.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/50.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Ground ;
#     foaf:name "Diglett" .
#
# pok:Ditto bibo:AudioDocument <sound/132%20-%20Ditto.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/132.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Normal ;
#     foaf:name "Ditto" .
#
# pok:Dodrio bibo:AudioDocument <sound/085%20-%20Dodrio.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/85.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Flying,
#         pok:Normal ;
#     foaf:name "Dodrio" .
#
# pok:Doduo bibo:AudioDocument <sound/084%20-%20Doduo.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/84.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Flying,
#         pok:Normal ;
#     foaf:name "Doduo" .
#
# pok:Donphan bibo:AudioDocument <sound/232%20-%20Donphan.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/232.png> ;
#     pok:hasRegion pok:Johto ;
#     pok:hasType pok:Ground ;
#     foaf:name "Donphan" .
#
# pok:Doublade bibo:AudioDocument <sound/680%20-%20Doublade.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/680.png> ;
#     pok:hasRegion pok:Kalos ;
#     pok:hasType pok:Ghost,
#         pok:Steel ;
#     foaf:name "Doublade" .
#
# pok:Dragalge bibo:AudioDocument <sound/691%20-%20Dragalge.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/691.png> ;
#     pok:hasRegion pok:Kalos ;
#     pok:hasType pok:Dragon,
#         pok:Poison ;
#     foaf:name "Dragalge" .
#
# pok:Dragonair bibo:AudioDocument <sound/148%20-%20Dragonair.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/148.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Dragon ;
#     foaf:name "Dragonair" .
#
# pok:Dragonite bibo:AudioDocument <sound/149%20-%20Dragonite.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/149.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Dragon,
#         pok:Flying ;
#     foaf:name "Dragonite" .
#
# pok:Drapion bibo:AudioDocument <sound/452%20-%20Drapion.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/452.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Dark,
#         pok:Poison ;
#     foaf:name "Drapion" .
#
# pok:Dratini bibo:AudioDocument <sound/147%20-%20Dratini.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/147.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Dragon ;
#     foaf:name "Dratini" .
#
# pok:Drifblim bibo:AudioDocument <sound/426%20-%20Drifblim.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/426.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Flying,
#         pok:Ghost ;
#     foaf:name "Drifblim" .
#
# pok:Drifloon bibo:AudioDocument <sound/425%20-%20Drifloon.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/425.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Flying,
#         pok:Ghost ;
#     foaf:name "Drifloon" .
#
# pok:Drilbur bibo:AudioDocument <sound/529%20-%20Drilbur.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/529.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Ground ;
#     foaf:name "Drilbur" .
#
# pok:Drowzee bibo:AudioDocument <sound/096%20-%20Drowzee.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/96.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Psychic ;
#     foaf:name "Drowzee" .
#
# pok:Druddigon bibo:AudioDocument <sound/621%20-%20Druddigon.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/621.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Dragon ;
#     foaf:name "Druddigon" .
#
# pok:Ducklett bibo:AudioDocument <sound/580%20-%20Ducklett.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/580.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Flying,
#         pok:Water ;
#     foaf:name "Ducklett" .
#
# pok:Dugtrio bibo:AudioDocument <sound/051%20-%20Dugtrio.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/51.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Ground ;
#     foaf:name "Dugtrio" .
#
# pok:Dunsparce bibo:AudioDocument <sound/206%20-%20Dunsparce.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/206.png> ;
#     pok:hasRegion pok:Johto ;
#     pok:hasType pok:Normal ;
#     foaf:name "Dunsparce" .
#
# pok:Duosion bibo:AudioDocument <sound/578%20-%20Duosion.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/578.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Psychic ;
#     foaf:name "Duosion" .
#
# pok:Durant bibo:AudioDocument <sound/632%20-%20Durant.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/632.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Bug,
#         pok:Steel ;
#     foaf:name "Durant" .
#
# pok:Dusclops bibo:AudioDocument <sound/356%20-%20Dusclops.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/356.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Ghost ;
#     foaf:name "Dusclops" .
#
# pok:Dusknoir bibo:AudioDocument <sound/477%20-%20Dusknoir.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/477.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Ghost ;
#     foaf:name "Dusknoir" .
#
# pok:Duskull bibo:AudioDocument <sound/355%20-%20Duskull.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/355.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Ghost ;
#     foaf:name "Duskull" .
#
# pok:Dustox bibo:AudioDocument <sound/269%20-%20Dustox.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/269.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Bug,
#         pok:Poison ;
#     foaf:name "Dustox" .
#
# pok:Dwebble bibo:AudioDocument <sound/557%20-%20Dwebble.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/557.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Bug,
#         pok:Rock ;
#     foaf:name "Dwebble" .
#
# pok:Eelektrik bibo:AudioDocument <sound/603%20-%20Eelektrik.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/603.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Electric ;
#     foaf:name "Eelektrik" .
#
# pok:Eelektross bibo:AudioDocument <sound/604%20-%20Eelektross.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/604.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Electric ;
#     foaf:name "Eelektross" .
#
# pok:Eevee bibo:AudioDocument <sound/133%20-%20Eevee.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/133.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Normal ;
#     foaf:name "Eevee" .
#
# pok:Ekans bibo:AudioDocument <sound/023%20-%20Ekans.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/23.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Poison ;
#     foaf:name "Ekans" .
#
# pok:Electabuzz bibo:AudioDocument <sound/125%20-%20Electabuzz.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/125.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Electric ;
#     foaf:name "Electabuzz" .
#
# pok:Electivire bibo:AudioDocument <sound/466%20-%20Electivire.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/466.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Electric ;
#     foaf:name "Electivire" .
#
# pok:Electrike bibo:AudioDocument <sound/309%20-%20Electrike.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/309.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Electric ;
#     foaf:name "Electrike" .
#
# pok:Electrode bibo:AudioDocument <sound/101%20-%20Electrode.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/101.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Electric ;
#     foaf:name "Electrode" .
#
# pok:Elekid bibo:AudioDocument <sound/239%20-%20Elekid.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/239.png> ;
#     pok:hasRegion pok:Johto ;
#     pok:hasType pok:Electric ;
#     foaf:name "Elekid" .
#
# pok:Elgyem bibo:AudioDocument <sound/605%20-%20Elgyem.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/605.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Psychic ;
#     foaf:name "Elgyem" .
#
# pok:Emboar bibo:AudioDocument <sound/500%20-%20Emboar.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/500.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Fighting,
#         pok:Fire ;
#     foaf:name "Emboar" .
#
# pok:Emolga bibo:AudioDocument <sound/587%20-%20Emolga.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/587.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Electric,
#         pok:Flying ;
#     foaf:name "Emolga" .
#
# pok:Empoleon bibo:AudioDocument <sound/395%20-%20Empoleon.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/395.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Steel,
#         pok:Water ;
#     foaf:name "Empoleon" .
#
# pok:Entei bibo:AudioDocument <sound/244%20-%20Entei.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/244.png> ;
#     pok:hasRegion pok:Johto ;
#     pok:hasType pok:Fire ;
#     foaf:name "Entei" .
#
# pok:Escavalier bibo:AudioDocument <sound/589%20-%20Escavalier.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/589.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Bug,
#         pok:Steel ;
#     foaf:name "Escavalier" .
#
# pok:Espeon bibo:AudioDocument <sound/196%20-%20Espeon.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/196.png> ;
#     pok:hasRegion pok:Johto ;
#     pok:hasType pok:Psychic ;
#     foaf:name "Espeon" .
#
# pok:Espurr bibo:AudioDocument <sound/677%20-%20Espurr.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/677.png> ;
#     pok:hasRegion pok:Kalos ;
#     pok:hasType pok:Psychic ;
#     foaf:name "Espurr" .
#
# pok:Excadrill bibo:AudioDocument <sound/530%20-%20Excadrill.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/530.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Ground,
#         pok:Steel ;
#     foaf:name "Excadrill" .
#
# pok:Exeggcute bibo:AudioDocument <sound/102%20-%20Exeggcute.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/102.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Grass,
#         pok:Psychic ;
#     foaf:name "Exeggcute" .
#
# pok:Exeggutor bibo:AudioDocument <sound/103%20-%20Exeggutor.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/103.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Grass,
#         pok:Psychic ;
#     foaf:name "Exeggutor" .
#
# pok:Exploud bibo:AudioDocument <sound/295%20-%20Exploud.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/295.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Normal ;
#     foaf:name "Exploud" .
#
# <http://www.example.org/pokemon/Farfetch'd> bibo:AudioDocument <sound/083%20-%20Farfetch%27d.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/83.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Flying,
#         pok:Normal ;
#     foaf:name "Farfetch'd" .
#
# pok:Fearow bibo:AudioDocument <sound/022%20-%20Fearow.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/22.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Flying,
#         pok:Normal ;
#     foaf:name "Fearow" .
#
# pok:Feebas bibo:AudioDocument <sound/349%20-%20Feebas.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/349.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Water ;
#     foaf:name "Feebas" .
#
# pok:Fennekin bibo:AudioDocument <sound/653%20-%20Fennekin.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/653.png> ;
#     pok:hasRegion pok:Kalos ;
#     pok:hasType pok:Fire ;
#     foaf:name "Fennekin" .
#
# pok:Feraligatr bibo:AudioDocument <sound/160%20-%20Feraligatr.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/160.png> ;
#     pok:hasRegion pok:Johto ;
#     pok:hasType pok:Water ;
#     foaf:name "Feraligatr" .
#
# pok:Ferroseed bibo:AudioDocument <sound/597%20-%20Ferroseed.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/597.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Grass,
#         pok:Steel ;
#     foaf:name "Ferroseed" .
#
# pok:Ferrothorn bibo:AudioDocument <sound/598%20-%20Ferrothorn.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/598.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Grass,
#         pok:Steel ;
#     foaf:name "Ferrothorn" .
#
# pok:Finneon bibo:AudioDocument <sound/456%20-%20Finneon.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/456.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Water ;
#     foaf:name "Finneon" .
#
# pok:Flaaffy bibo:AudioDocument <sound/180%20-%20Flaaffy.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/180.png> ;
#     pok:hasRegion pok:Johto ;
#     pok:hasType pok:Electric ;
#     foaf:name "Flaaffy" .
#
# pok:Flabébé bibo:AudioDocument <sound/669%20-%20Flab%C3%A9b%C3%A9.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/669.png> ;
#     pok:hasRegion pok:Kalos ;
#     pok:hasType pok:Fairy ;
#     foaf:name "Flabébé" .
#
# pok:Flareon bibo:AudioDocument <sound/136%20-%20Flareon.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/136.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Fire ;
#     foaf:name "Flareon" .
#
# pok:Fletchinder bibo:AudioDocument <sound/662%20-%20Fletchinder.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/662.png> ;
#     pok:hasRegion pok:Kalos ;
#     pok:hasType pok:Fire,
#         pok:Flying ;
#     foaf:name "Fletchinder" .
#
# pok:Fletchling bibo:AudioDocument <sound/661%20-%20Fletchling.wav> ;
# ...
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Bug,
#         pok:Poison ;
#     foaf:name "Weedle" .
#
# pok:Weepinbell bibo:AudioDocument <sound/070%20-%20Weepinbell.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/70.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Grass,
#         pok:Poison ;
#     foaf:name "Weepinbell" .
#
# pok:Weezing bibo:AudioDocument <sound/110%20-%20Weezing.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/110.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Poison ;
#     foaf:name "Weezing" .
#
# pok:Whimsicott bibo:AudioDocument <sound/547%20-%20Whimsicott.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/547.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Fairy,
#         pok:Grass ;
#     foaf:name "Whimsicott" .
#
# pok:Whirlipede bibo:AudioDocument <sound/544%20-%20Whirlipede.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/544.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Bug,
#         pok:Poison ;
#     foaf:name "Whirlipede" .
#
# pok:Whiscash bibo:AudioDocument <sound/340%20-%20Whiscash.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/340.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Ground,
#         pok:Water ;
#     foaf:name "Whiscash" .
#
# pok:Whismur bibo:AudioDocument <sound/293%20-%20Whismur.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/293.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Normal ;
#     foaf:name "Whismur" .
#
# pok:Wigglytuff bibo:AudioDocument <sound/040%20-%20Wigglytuff.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/40.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Fairy,
#         pok:Normal ;
#     foaf:name "Wigglytuff" .
#
# pok:Wingull bibo:AudioDocument <sound/278%20-%20Wingull.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/278.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Flying,
#         pok:Water ;
#     foaf:name "Wingull" .
#
# pok:Wobbuffet bibo:AudioDocument <sound/202%20-%20Wobbuffet.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/202.png> ;
#     pok:hasRegion pok:Johto ;
#     pok:hasType pok:Psychic ;
#     foaf:name "Wobbuffet" .
#
# pok:Woobat bibo:AudioDocument <sound/527%20-%20Woobat.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/527.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Flying,
#         pok:Psychic ;
#     foaf:name "Woobat" .
#
# pok:Wooper bibo:AudioDocument <sound/194%20-%20Wooper.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/194.png> ;
#     pok:hasRegion pok:Johto ;
#     pok:hasType pok:Ground,
#         pok:Water ;
#     foaf:name "Wooper" .
#
# pok:Wormadam bibo:AudioDocument <sound/413%20-%20Wormadam.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/413.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Bug,
#         pok:Grass ;
#     foaf:name "Wormadam" .
#
# pok:Wurmple bibo:AudioDocument <sound/265%20-%20Wurmple.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/265.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Bug ;
#     foaf:name "Wurmple" .
#
# pok:Wynaut bibo:AudioDocument <sound/360%20-%20Wynaut.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/360.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Psychic ;
#     foaf:name "Wynaut" .
#
# pok:Xatu bibo:AudioDocument <sound/178%20-%20Xatu.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/178.png> ;
#     pok:hasRegion pok:Johto ;
#     pok:hasType pok:Flying,
#         pok:Psychic ;
#     foaf:name "Xatu" .
#
# pok:Xerneas bibo:AudioDocument <sound/716%20-%20Xerneas.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/716.png> ;
#     pok:hasRegion pok:Kalos ;
#     pok:hasType pok:Fairy ;
#     foaf:name "Xerneas" .
#
# pok:Yamask bibo:AudioDocument <sound/562%20-%20Yamask.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/562.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Ghost ;
#     foaf:name "Yamask" .
#
# pok:Yanma bibo:AudioDocument <sound/193%20-%20Yanma.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/193.png> ;
#     pok:hasRegion pok:Johto ;
#     pok:hasType pok:Bug,
#         pok:Flying ;
#     foaf:name "Yanma" .
#
# pok:Yanmega bibo:AudioDocument <sound/469%20-%20Yanmega.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/469.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Bug,
#         pok:Flying ;
#     foaf:name "Yanmega" .
#
# pok:Yveltal bibo:AudioDocument <sound/717%20-%20Yveltal.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/717.png> ;
#     pok:hasRegion pok:Kalos ;
#     pok:hasType pok:Dark,
#         pok:Flying ;
#     foaf:name "Yveltal" .
#
# pok:Zangoose bibo:AudioDocument <sound/335%20-%20Zangoose.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/335.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Normal ;
#     foaf:name "Zangoose" .
#
# pok:Zapdos bibo:AudioDocument <sound/145%20-%20Zapdos.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/145.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Electric,
#         pok:Flying ;
#     foaf:name "Zapdos" .
#
# pok:Zebstrika bibo:AudioDocument <sound/523%20-%20Zebstrika.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/523.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Electric ;
#     foaf:name "Zebstrika" .
#
# pok:Zekrom bibo:AudioDocument <sound/644%20-%20Zekrom.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/644.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Dragon,
#         pok:Electric ;
#     foaf:name "Zekrom" .
#
# pok:Zigzagoon bibo:AudioDocument <sound/263%20-%20Zigzagoon.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/263.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Normal ;
#     foaf:name "Zigzagoon" .
#
# pok:Zoroark bibo:AudioDocument <sound/571%20-%20Zoroark.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/571.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Dark ;
#     foaf:name "Zoroark" .
#
# pok:Zorua bibo:AudioDocument <sound/570%20-%20Zorua.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/570.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Dark ;
#     foaf:name "Zorua" .
#
# pok:Zubat bibo:AudioDocument <sound/041%20-%20Zubat.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/41.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Flying,
#         pok:Poison ;
#     foaf:name "Zubat" .
#
# pok:Zweilous bibo:AudioDocument <sound/634%20-%20Zweilous.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/634.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Dark,
#         pok:Dragon ;
#     foaf:name "Zweilous" .
#
# pok:Zygarde bibo:AudioDocument <sound/718%20-%20Zygarde.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/718.png> ;
#     pok:hasRegion pok:Kalos ;
#     pok:hasType pok:Dragon,
#         pok:Ground ;
#     foaf:name "Zygarde" .
#
# pok:hasItem a owl:ObjectProperty ;
#     rdfs:range pok:Pokéball .
#
# pok:hasPokemon a owl:ObjectProperty ;
#     rdfs:domain pok:Trainer .
#
# pok:hasRegion a owl:ObjectProperty ;
#     rdfs:range pok:Region .
#
# pok:hasType a owl:ObjectProperty ;
#     rdfs:domain pok:Pokémon ;
#     rdfs:range pok:Typing .
#
# foaf:name a owl:ObjectProperty .
#
# pok:Arcanine bibo:AudioDocument <sound/059%20-%20Arcanine.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/59.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Fire ;
#     foaf:name "Arcanine" .
#
# pok:Blastoise bibo:AudioDocument <sound/009%20-%20Blastoise.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/9.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Water ;
#     foaf:name "Blastoise" .
#
# pok:Charizard bibo:AudioDocument <sound/006%20-%20Charizard.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/6.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Fire,
#         pok:Flying ;
#     foaf:name "Charizard" .
#
# pok:Onix bibo:AudioDocument <sound/095%20-%20Onix.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/95.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Ground,
#         pok:Rock ;
#     foaf:name "Onix" .
#
# pok:Pikachu bibo:AudioDocument <sound/025%20-%20Pikachu.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/25.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Electric ;
#     foaf:name "Pikachu" .
#
# pok:Psyduck bibo:AudioDocument <sound/054%20-%20Psyduck.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/54.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Water ;
#     foaf:name "Psyduck" .
#
# pok:Togepi bibo:AudioDocument <sound/175%20-%20Togepi.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/175.png> ;
#     pok:hasRegion pok:Johto ;
#     pok:hasType pok:Fairy ;
#     foaf:name "Togepi" .
#
# pok:Ice pok:NeutralTo pok:Bug,
#         pok:Dark,
#         pok:Electric,
#         pok:Fairy,
#         pok:Fighting,
#         pok:Ghost,
#         pok:Normal,
#         pok:Poison,
#         pok:Psychic,
#         pok:Rock ;
#     pok:StrongTo pok:Dragon,
#         pok:Flying,
#         pok:Grass,
#         pok:Ground ;
#     pok:WeakTo pok:Fire,
#         pok:Ice,
#         pok:Steel,
#         pok:Water .
#
# pok:Fairy pok:NeutralTo pok:Bug,
#         pok:Electric,
#         pok:Fairy,
#         pok:Flying,
#         pok:Ghost,
#         pok:Grass,
#         pok:Ground,
#         pok:Ice,
#         pok:Normal,
#         pok:Psychic,
#         pok:Rock,
#         pok:Water ;
#     pok:StrongTo pok:Dark,
#         pok:Dragon,
#         pok:Fighting ;
#     pok:WeakTo pok:Fire,
#         pok:Poison,
#         pok:Steel .
#
# pok:Ghost pok:NeutralTo pok:Bug,
#         pok:Dragon,
#         pok:Electric,
#         pok:Fairy,
#         pok:Fighting,
#         pok:Fire,
#         pok:Flying,
#         pok:Grass,
#         pok:Ground,
#         pok:Ice,
#         pok:Poison,
#         pok:Rock,
#         pok:Steel,
#         pok:Water ;
#     pok:StrongTo pok:Ghost,
#         pok:Psychic ;
#     pok:WeakTo pok:Dark,
#         pok:Normal .
#
# pok:Dragon pok:NeutralTo pok:Bug,
#         pok:Dark,
#         pok:Electric,
#         pok:Fighting,
#         pok:Fire,
#         pok:Flying,
#         pok:Ghost,
#         pok:Grass,
#         pok:Ground,
#         pok:Ice,
#         pok:Normal,
#         pok:Poison,
#         pok:Psychic,
#         pok:Rock,
#         pok:Water ;
#     pok:StrongTo pok:Dragon ;
#     pok:WeakTo pok:Fairy,
#         pok:Steel .
#
# pok:Steel pok:NeutralTo pok:Bug,
#         pok:Dark,
#         pok:Dragon,
#         pok:Electric,
#         pok:Fighting,
#         pok:Flying,
#         pok:Ghost,
#         pok:Grass,
#         pok:Ground,
#         pok:Normal,
#         pok:Psychic ;
#     pok:StrongTo pok:Fairy,
#         pok:Ice,
#         pok:Rock ;
#     pok:WeakTo pok:Fire,
#         pok:Poison,
#         pok:Steel,
#         pok:Water .
#
# pok:Electric pok:NeutralTo pok:Bug,
#         pok:Dark,
#         pok:Fairy,
#         pok:Fighting,
#         pok:Fire,
#         pok:Ghost,
#         pok:Ice,
#         pok:Normal,
#         pok:Poison,
#         pok:Psychic,
#         pok:Rock,
#         pok:Steel ;
#     pok:StrongTo pok:Flying,
#         pok:Water ;
#     pok:WeakTo pok:Dragon,
#         pok:Electric,
#         pok:Grass,
#         pok:Ground .
#
# pok:Dark pok:NeutralTo pok:Bug,
#         pok:Dragon,
#         pok:Electric,
#         pok:Fire,
#         pok:Flying,
#         pok:Grass,
#         pok:Ground,
#         pok:Ice,
#         pok:Normal,
#         pok:Poison,
#         pok:Rock,
#         pok:Steel,
#         pok:Water ;
#     pok:StrongTo pok:Ghost,
#         pok:Psychic ;
#     pok:WeakTo pok:Dark,
#         pok:Fairy,
#         pok:Fighting .
#
# pok:Fighting pok:NeutralTo pok:Dragon,
#         pok:Electric,
#         pok:Fighting,
#         pok:Fire,
#         pok:Grass,
#         pok:Ground,
#         pok:Water ;
#     pok:StrongTo pok:Dark,
#         pok:Ice,
#         pok:Normal,
#         pok:Rock,
#         pok:Steel ;
#     pok:WeakTo pok:Bug,
#         pok:Fairy,
#         pok:Flying,
#         pok:Ghost,
#         pok:Poison,
#         pok:Psychic .
#
# pok:Rock pok:NeutralTo pok:Dark,
#         pok:Dragon,
#         pok:Electric,
#         pok:Fairy,
#         pok:Ghost,
#         pok:Grass,
#         pok:Normal,
#         pok:Poison,
#         pok:Psychic,
#         pok:Rock,
#         pok:Water ;
#     pok:StrongTo pok:Bug,
#         pok:Fire,
#         pok:Flying,
#         pok:Ice ;
#     pok:WeakTo pok:Fighting,
#         pok:Ground,
#         pok:Steel .
#
# pok:Fire pok:NeutralTo pok:Dark,
#         pok:Electric,
#         pok:Fairy,
#         pok:Fighting,
#         pok:Flying,
#         pok:Ghost,
#         pok:Ground,
#         pok:Normal,
#         pok:Poison,
#         pok:Psychic ;
#     pok:StrongTo pok:Bug,
#         pok:Grass,
#         pok:Ice,
#         pok:Steel ;
#     pok:WeakTo pok:Dragon,
#         pok:Fire,
#         pok:Rock,
#         pok:Water .
#
# pok:Poison pok:NeutralTo pok:Bug,
#         pok:Dark,
#         pok:Dragon,
#         pok:Electric,
#         pok:Fighting,
#         pok:Fire,
#         pok:Flying,
#         pok:Ice,
#         pok:Normal,
#         pok:Psychic,
#         pok:Water ;
#     pok:StrongTo pok:Fairy,
#         pok:Grass ;
#     pok:WeakTo pok:Ghost,
#         pok:Ground,
#         pok:Poison,
#         pok:Rock,
#         pok:Steel .
#
# pok:Ground pok:NeutralTo pok:Dark,
#         pok:Dragon,
#         pok:Fairy,
#         pok:Fighting,
#         pok:Ghost,
#         pok:Ground,
#         pok:Ice,
#         pok:Normal,
#         pok:Psychic,
#         pok:Water ;
#     pok:StrongTo pok:Electric,
#         pok:Fire,
#         pok:Poison,
#         pok:Rock,
#         pok:Steel ;
#     pok:WeakTo pok:Bug,
#         pok:Flying,
#         pok:Grass .
#
# pok:Bug pok:NeutralTo pok:Bug,
#         pok:Dragon,
#         pok:Electric,
#         pok:Ground,
#         pok:Ice,
#         pok:Normal,
#         pok:Rock,
#         pok:Water ;
#     pok:StrongTo pok:Dark,
#         pok:Grass,
#         pok:Psychic ;
#     pok:WeakTo pok:Fairy,
#         pok:Fighting,
#         pok:Fire,
#         pok:Flying,
#         pok:Ghost,
#         pok:Poison,
#         pok:Steel .
#
# pok:Psychic pok:NeutralTo pok:Bug,
#         pok:Dragon,
#         pok:Electric,
#         pok:Fairy,
#         pok:Fire,
#         pok:Flying,
#         pok:Ghost,
#         pok:Grass,
#         pok:Ground,
#         pok:Ice,
#         pok:Normal,
#         pok:Rock,
#         pok:Water ;
#     pok:StrongTo pok:Fighting,
#         pok:Poison ;
#     pok:WeakTo pok:Dark,
#         pok:Psychic,
#         pok:Steel .
#
# pok:Grass pok:NeutralTo pok:Dark,
#         pok:Electric,
#         pok:Fairy,
#         pok:Fighting,
#         pok:Ghost,
#         pok:Ice,
#         pok:Normal,
#         pok:Psychic ;
#     pok:StrongTo pok:Ground,
#         pok:Rock,
#         pok:Water ;
#     pok:WeakTo pok:Bug,
#         pok:Dragon,
#         pok:Fire,
#         pok:Flying,
#         pok:Grass,
#         pok:Poison,
#         pok:Steel .
#
# pok:Flying pok:NeutralTo pok:Dark,
#         pok:Dragon,
#         pok:Fairy,
#         pok:Fire,
#         pok:Flying,
#         pok:Ghost,
#         pok:Ground,
#         pok:Ice,
#         pok:Normal,
#         pok:Poison,
#         pok:Psychic,
#         pok:Water ;
#     pok:StrongTo pok:Bug,
#         pok:Fighting,
#         pok:Grass ;
#     pok:WeakTo pok:Electric,
#         pok:Rock,
#         pok:Steel .
#
# pok:Normal pok:NeutralTo pok:Bug,
#         pok:Dark,
#         pok:Dragon,
#         pok:Electric,
#         pok:Fairy,
#         pok:Fighting,
#         pok:Fire,
#         pok:Flying,
#         pok:Grass,
#         pok:Ground,
#         pok:Ice,
#         pok:Normal,
#         pok:Poison,
#         pok:Psychic,
#         pok:Water ;
#     pok:WeakTo pok:Ghost,
#         pok:Rock,
#         pok:Steel .
#
# pok:Water pok:NeutralTo pok:Bug,
#         pok:Dark,
#         pok:Electric,
#         pok:Fairy,
#         pok:Fighting,
#         pok:Flying,
#         pok:Ghost,
#         pok:Ice,
#         pok:Normal,
#         pok:Poison,
#         pok:Psychic,
#         pok:Steel ;
#     pok:StrongTo pok:Fire,
#         pok:Ground,
#         pok:Rock ;
#     pok:WeakTo pok:Dragon,
#         pok:Grass,
#         pok:Water .

# %%
pokegraph.serialize(destination="pokemon.ttl", format='turtle')

# %%
<option value="Bulbasaur">

# %%
poklist = ""
with open ('Pokemon.csv') as f:
    for line in f:
        split = line.split(',')[1:]
        
        print("<option value=\"" + str(split[0]) + "\">")
# Out:
# <option value="Name">
# <option value="Bulbasaur">
# <option value="Ivysaur">
# <option value="Venusaur">
# <option value="Charmander">
# <option value="Charmeleon">
# <option value="Charizard">
# <option value="Squirtle">
# <option value="Wartortle">
# <option value="Blastoise">
# <option value="Caterpie">
# <option value="Metapod">
# <option value="Butterfree">
# <option value="Weedle">
# <option value="Kakuna">
# <option value="Beedrill">
# <option value="Pidgey">
# <option value="Pidgeotto">
# <option value="Pidgeot">
# <option value="Rattata">
# <option value="Raticate">
# <option value="Spearow">
# <option value="Fearow">
# <option value="Ekans">
# <option value="Arbok">
# <option value="Pikachu">
# <option value="Raichu">
# <option value="Sandshrew">
# <option value="Sandslash">
# <option value="Nidoran♀">
# <option value="Nidorina">
# <option value="Nidoqueen">
# <option value="Nidoran♂">
# <option value="Nidorino">
# <option value="Nidoking">
# <option value="Clefairy">
# <option value="Clefable">
# <option value="Vulpix">
# <option value="Ninetales">
# <option value="Jigglypuff">
# <option value="Wigglytuff">
# <option value="Zubat">
# <option value="Golbat">
# <option value="Oddish">
# <option value="Gloom">
# <option value="Vileplume">
# <option value="Paras">
# <option value="Parasect">
# <option value="Venonat">
# <option value="Venomoth">
# <option value="Diglett">
# <option value="Dugtrio">
# <option value="Meowth">
# <option value="Persian">
# <option value="Psyduck">
# <option value="Golduck">
# <option value="Mankey">
# <option value="Primeape">
# <option value="Growlithe">
# <option value="Arcanine">
# <option value="Poliwag">
# <option value="Poliwhirl">
# <option value="Poliwrath">
# <option value="Abra">
# <option value="Kadabra">
# <option value="Alakazam">
# <option value="Machop">
# <option value="Machoke">
# <option value="Machamp">
# <option value="Bellsprout">
# <option value="Weepinbell">
# <option value="Victreebel">
# <option value="Tentacool">
# <option value="Tentacruel">
# <option value="Geodude">
# <option value="Graveler">
# <option value="Golem">
# <option value="Ponyta">
# <option value="Rapidash">
# <option value="Slowpoke">
# <option value="Slowbro">
# <option value="Magnemite">
# <option value="Magneton">
# <option value="Farfetch'd">
# <option value="Doduo">
# <option value="Dodrio">
# <option value="Seel">
# <option value="Dewgong">
# <option value="Grimer">
# <option value="Muk">
# <option value="Shellder">
# <option value="Cloyster">
# <option value="Gastly">
# <option value="Haunter">
# <option value="Gengar">
# <option value="Onix">
# <option value="Drowzee">
# <option value="Hypno">
# <option value="Krabby">
# <option value="Kingler">
# <option value="Voltorb">
# <option value="Electrode">
# <option value="Exeggcute">
# <option value="Exeggutor">
# <option value="Cubone">
# <option value="Marowak">
# <option value="Hitmonlee">
# <option value="Hitmonchan">
# <option value="Lickitung">
# <option value="Koffing">
# <option value="Weezing">
# <option value="Rhyhorn">
# <option value="Rhydon">
# <option value="Chansey">
# <option value="Tangela">
# <option value="Kangaskhan">
# <option value="Horsea">
# <option value="Seadra">
# <option value="Goldeen">
# <option value="Seaking">
# <option value="Staryu">
# <option value="Starmie">
# <option value="Mr. Mime">
# <option value="Scyther">
# <option value="Jynx">
# <option value="Electabuzz">
# <option value="Magmar">
# <option value="Pinsir">
# <option value="Tauros">
# <option value="Magikarp">
# <option value="Gyarados">
# <option value="Lapras">
# <option value="Ditto">
# <option value="Eevee">
# <option value="Vaporeon">
# <option value="Jolteon">
# <option value="Flareon">
# <option value="Porygon">
# <option value="Omanyte">
# <option value="Omastar">
# <option value="Kabuto">
# <option value="Kabutops">
# <option value="Aerodactyl">
# <option value="Snorlax">
# <option value="Articuno">
# <option value="Zapdos">
# <option value="Moltres">
# <option value="Dratini">
# <option value="Dragonair">
# <option value="Dragonite">
# <option value="Mewtwo">
# <option value="Mew">
# <option value="Chikorita">
# <option value="Bayleef">
# <option value="Meganium">
# <option value="Cyndaquil">
# <option value="Quilava">
# <option value="Typhlosion">
# <option value="Totodile">
# <option value="Croconaw">
# <option value="Feraligatr">
# <option value="Sentret">
# <option value="Furret">
# <option value="Hoothoot">
# <option value="Noctowl">
# <option value="Ledyba">
# <option value="Ledian">
# <option value="Spinarak">
# <option value="Ariados">
# <option value="Crobat">
# <option value="Chinchou">
# <option value="Lanturn">
# <option value="Pichu">
# <option value="Cleffa">
# <option value="Igglybuff">
# <option value="Togepi">
# <option value="Togetic">
# <option value="Natu">
# <option value="Xatu">
# <option value="Mareep">
# <option value="Flaaffy">
# <option value="Ampharos">
# <option value="Bellossom">
# <option value="Marill">
# <option value="Azumarill">
# <option value="Sudowoodo">
# <option value="Politoed">
# <option value="Hoppip">
# <option value="Skiploom">
# <option value="Jumpluff">
# <option value="Aipom">
# <option value="Sunkern">
# <option value="Sunflora">
# <option value="Yanma">
# <option value="Wooper">
# <option value="Quagsire">
# <option value="Espeon">
# <option value="Umbreon">
# <option value="Murkrow">
# <option value="Slowking">
# <option value="Misdreavus">
# <option value="Unown">
# <option value="Wobbuffet">
# <option value="Girafarig">
# <option value="Pineco">
# <option value="Forretress">
# <option value="Dunsparce">
# <option value="Gligar">
# <option value="Steelix">
# <option value="Snubbull">
# <option value="Granbull">
# <option value="Qwilfish">
# <option value="Scizor">
# <option value="Shuckle">
# <option value="Heracross">
# <option value="Sneasel">
# <option value="Teddiursa">
# <option value="Ursaring">
# <option value="Slugma">
# <option value="Magcargo">
# <option value="Swinub">
# <option value="Piloswine">
# <option value="Corsola">
# <option value="Remoraid">
# <option value="Octillery">
# <option value="Delibird">
# <option value="Mantine">
# <option value="Skarmory">
# <option value="Houndour">
# <option value="Houndoom">
# <option value="Kingdra">
# <option value="Phanpy">
# <option value="Donphan">
# <option value="Porygon2">
# <option value="Stantler">
# <option value="Smeargle">
# <option value="Tyrogue">
# <option value="Hitmontop">
# <option value="Smoochum">
# <option value="Elekid">
# <option value="Magby">
# <option value="Miltank">
# <option value="Blissey">
# <option value="Raikou">
# <option value="Entei">
# <option value="Suicune">
# <option value="Larvitar">
# <option value="Pupitar">
# <option value="Tyranitar">
# <option value="Lugia">
# <option value="Ho-oh">
# <option value="Celebi">
# <option value="Treecko">
# <option value="Grovyle">
# <option value="Sceptile">
# <option value="Torchic">
# <option value="Combusken">
# <option value="Blaziken">
# <option value="Mudkip">
# <option value="Marshtomp">
# <option value="Swampert">
# <option value="Poochyena">
# <option value="Mightyena">
# <option value="Zigzagoon">
# <option value="Linoone">
# <option value="Wurmple">
# <option value="Silcoon">
# <option value="Beautifly">
# <option value="Cascoon">
# <option value="Dustox">
# <option value="Lotad">
# <option value="Lombre">
# <option value="Ludicolo">
# <option value="Seedot">
# <option value="Nuzleaf">
# <option value="Shiftry">
# <option value="Taillow">
# <option value="Swellow">
# <option value="Wingull">
# <option value="Pelipper">
# <option value="Ralts">
# <option value="Kirlia">
# <option value="Gardevoir">
# <option value="Surskit">
# <option value="Masquerain">
# <option value="Shroomish">
# <option value="Breloom">
# <option value="Slakoth">
# <option value="Vigoroth">
# <option value="Slaking">
# <option value="Nincada">
# <option value="Ninjask">
# <option value="Shedinja">
# <option value="Whismur">
# <option value="Loudred">
# <option value="Exploud">
# <option value="Makuhita">
# <option value="Hariyama">
# <option value="Azurill">
# <option value="Nosepass">
# <option value="Skitty">
# <option value="Delcatty">
# <option value="Sableye">
# <option value="Mawile">
# <option value="Aron">
# <option value="Lairon">
# <option value="Aggron">
# <option value="Meditite">
# <option value="Medicham">
# <option value="Electrike">
# <option value="Manectric">
# <option value="Plusle">
# <option value="Minun">
# <option value="Volbeat">
# <option value="Illumise">
# <option value="Roselia">
# <option value="Gulpin">
# <option value="Swalot">
# <option value="Carvanha">
# <option value="Sharpedo">
# <option value="Wailmer">
# <option value="Wailord">
# <option value="Numel">
# <option value="Camerupt">
# <option value="Torkoal">
# <option value="Spoink">
# <option value="Grumpig">
# <option value="Spinda">
# <option value="Trapinch">
# <option value="Vibrava">
# <option value="Flygon">
# <option value="Cacnea">
# <option value="Cacturne">
# <option value="Swablu">
# <option value="Altaria">
# <option value="Zangoose">
# <option value="Seviper">
# <option value="Lunatone">
# <option value="Solrock">
# <option value="Barboach">
# <option value="Whiscash">
# <option value="Corphish">
# <option value="Crawdaunt">
# <option value="Baltoy">
# <option value="Claydol">
# <option value="Lileep">
# <option value="Cradily">
# <option value="Anorith">
# <option value="Armaldo">
# <option value="Feebas">
# <option value="Milotic">
# <option value="Castform">
# <option value="Kecleon">
# <option value="Shuppet">
# <option value="Banette">
# <option value="Duskull">
# <option value="Dusclops">
# <option value="Tropius">
# <option value="Chimecho">
# <option value="Absol">
# <option value="Wynaut">
# <option value="Snorunt">
# <option value="Glalie">
# <option value="Spheal">
# <option value="Sealeo">
# <option value="Walrein">
# <option value="Clamperl">
# <option value="Huntail">
# <option value="Gorebyss">
# <option value="Relicanth">
# <option value="Luvdisc">
# <option value="Bagon">
# <option value="Shelgon">
# <option value="Salamence">
# <option value="Beldum">
# <option value="Metang">
# <option value="Metagross">
# <option value="Regirock">
# <option value="Regice">
# <option value="Registeel">
# <option value="Latias">
# <option value="Latios">
# <option value="Kyogre">
# <option value="Groudon">
# <option value="Rayquaza">
# <option value="Jirachi">
# <option value="Deoxys">
# <option value="Turtwig">
# <option value="Grotle">
# <option value="Torterra">
# <option value="Chimchar">
# <option value="Monferno">
# <option value="Infernape">
# <option value="Piplup">
# <option value="Prinplup">
# <option value="Empoleon">
# <option value="Starly">
# <option value="Staravia">
# <option value="Staraptor">
# <option value="Bidoof">
# <option value="Bibarel">
# <option value="Kricketot">
# <option value="Kricketune">
# <option value="Shinx">
# <option value="Luxio">
# <option value="Luxray">
# <option value="Budew">
# <option value="Roserade">
# <option value="Cranidos">
# <option value="Rampardos">
# <option value="Shieldon">
# <option value="Bastiodon">
# <option value="Burmy">
# <option value="Wormadam">
# <option value="Mothim">
# <option value="Combee">
# <option value="Vespiquen">
# <option value="Pachirisu">
# <option value="Buizel">
# <option value="Floatzel">
# <option value="Cherubi">
# <option value="Cherrim">
# <option value="Shellos">
# <option value="Gastrodon">
# <option value="Ambipom">
# <option value="Drifloon">
# <option value="Drifblim">
# <option value="Buneary">
# <option value="Lopunny">
# <option value="Mismagius">
# <option value="Honchkrow">
# <option value="Glameow">
# <option value="Purugly">
# <option value="Chingling">
# <option value="Stunky">
# <option value="Skuntank">
# <option value="Bronzor">
# <option value="Bronzong">
# <option value="Bonsly">
# <option value="Mime Jr.">
# <option value="Happiny">
# <option value="Chatot">
# <option value="Spiritomb">
# <option value="Gible">
# <option value="Gabite">
# <option value="Garchomp">
# <option value="Munchlax">
# <option value="Riolu">
# <option value="Lucario">
# <option value="Hippopotas">
# <option value="Hippowdon">
# <option value="Skorupi">
# <option value="Drapion">
# <option value="Croagunk">
# <option value="Toxicroak">
# <option value="Carnivine">
# <option value="Finneon">
# <option value="Lumineon">
# <option value="Mantyke">
# <option value="Snover">
# <option value="Abomasnow">
# <option value="Weavile">
# <option value="Magnezone">
# <option value="Lickilicky">
# <option value="Rhyperior">
# <option value="Tangrowth">
# <option value="Electivire">
# <option value="Magmortar">
# <option value="Togekiss">
# <option value="Yanmega">
# <option value="Leafeon">
# <option value="Glaceon">
# <option value="Gliscor">
# <option value="Mamoswine">
# <option value="Porygon-Z">
# <option value="Gallade">
# <option value="Probopass">
# <option value="Dusknoir">
# <option value="Froslass">
# <option value="Rotom">
# <option value="Uxie">
# <option value="Mesprit">
# <option value="Azelf">
# <option value="Dialga">
# <option value="Palkia">
# <option value="Heatran">
# <option value="Regigigas">
# <option value="Giratina">
# <option value="Cresselia">
# <option value="Phione">
# <option value="Manaphy">
# <option value="Darkrai">
# <option value="Shaymin">
# <option value="Arceus">
# <option value="Victini">
# <option value="Snivy">
# <option value="Servine">
# <option value="Serperior">
# <option value="Tepig">
# <option value="Pignite">
# <option value="Emboar">
# <option value="Oshawott">
# <option value="Dewott">
# <option value="Samurott">
# <option value="Patrat">
# <option value="Watchog">
# <option value="Lillipup">
# <option value="Herdier">
# <option value="Stoutland">
# <option value="Purrloin">
# <option value="Liepard">
# <option value="Pansage">
# <option value="Simisage">
# <option value="Pansear">
# <option value="Simisear">
# <option value="Panpour">
# <option value="Simipour">
# <option value="Munna">
# <option value="Musharna">
# <option value="Pidove">
# <option value="Tranquill">
# <option value="Unfezant">
# <option value="Blitzle">
# <option value="Zebstrika">
# <option value="Roggenrola">
# <option value="Boldore">
# <option value="Gigalith">
# <option value="Woobat">
# <option value="Swoobat">
# <option value="Drilbur">
# <option value="Excadrill">
# <option value="Audino">
# <option value="Timburr">
# <option value="Gurdurr">
# <option value="Conkeldurr">
# <option value="Tympole">
# <option value="Palpitoad">
# <option value="Seismitoad">
# <option value="Throh">
# <option value="Sawk">
# <option value="Sewaddle">
# <option value="Swadloon">
# <option value="Leavanny">
# <option value="Venipede">
# <option value="Whirlipede">
# <option value="Scolipede">
# <option value="Cottonee">
# <option value="Whimsicott">
# <option value="Petilil">
# <option value="Lilligant">
# <option value="Basculin">
# <option value="Sandile">
# <option value="Krokorok">
# <option value="Krookodile">
# <option value="Darumaka">
# <option value="Darmanitan">
# <option value="Maractus">
# <option value="Dwebble">
# <option value="Crustle">
# <option value="Scraggy">
# <option value="Scrafty">
# <option value="Sigilyph">
# <option value="Yamask">
# <option value="Cofagrigus">
# <option value="Tirtouga">
# <option value="Carracosta">
# <option value="Archen">
# <option value="Archeops">
# <option value="Trubbish">
# <option value="Garbodor">
# <option value="Zorua">
# <option value="Zoroark">
# <option value="Minccino">
# <option value="Cinccino">
# <option value="Gothita">
# <option value="Gothorita">
# <option value="Gothitelle">
# <option value="Solosis">
# <option value="Duosion">
# <option value="Reuniclus">
# <option value="Ducklett">
# <option value="Swanna">
# <option value="Vanillite">
# <option value="Vanillish">
# <option value="Vanilluxe">
# <option value="Deerling">
# <option value="Sawsbuck">
# <option value="Emolga">
# <option value="Karrablast">
# <option value="Escavalier">
# <option value="Foongus">
# <option value="Amoonguss">
# <option value="Frillish">
# <option value="Jellicent">
# <option value="Alomomola">
# <option value="Joltik">
# <option value="Galvantula">
# <option value="Ferroseed">
# <option value="Ferrothorn">
# <option value="Klink">
# <option value="Klang">
# <option value="Klinklang">
# <option value="Tynamo">
# <option value="Eelektrik">
# <option value="Eelektross">
# <option value="Elgyem">
# <option value="Beheeyem">
# <option value="Litwick">
# <option value="Lampent">
# <option value="Chandelure">
# <option value="Axew">
# <option value="Fraxure">
# <option value="Haxorus">
# <option value="Cubchoo">
# <option value="Beartic">
# <option value="Cryogonal">
# <option value="Shelmet">
# <option value="Accelgor">
# <option value="Stunfisk">
# <option value="Mienfoo">
# <option value="Mienshao">
# <option value="Druddigon">
# <option value="Golett">
# <option value="Golurk">
# <option value="Pawniard">
# <option value="Bisharp">
# <option value="Bouffalant">
# <option value="Rufflet">
# <option value="Braviary">
# <option value="Vullaby">
# <option value="Mandibuzz">
# <option value="Heatmor">
# <option value="Durant">
# <option value="Deino">
# <option value="Zweilous">
# <option value="Hydreigon">
# <option value="Larvesta">
# <option value="Volcarona">
# <option value="Cobalion">
# <option value="Terrakion">
# <option value="Virizion">
# <option value="Tornadus">
# <option value="Thundurus">
# <option value="Reshiram">
# <option value="Zekrom">
# <option value="Landorus">
# <option value="Kyurem">
# <option value="Keldeo">
# <option value="Meloetta">
# <option value="Genesect">
# <option value="Chespin">
# <option value="Quilladin">
# <option value="Chesnaught">
# <option value="Fennekin">
# <option value="Braixen">
# <option value="Delphox">
# <option value="Froakie">
# <option value="Frogadier">
# <option value="Greninja">
# <option value="Bunnelby">
# <option value="Diggersby">
# <option value="Fletchling">
# <option value="Fletchinder">
# <option value="Talonflame">
# <option value="Scatterbug">
# <option value="Spewpa">
# <option value="Vivillon">
# <option value="Litleo">
# <option value="Pyroar">
# <option value="Flabébé">
# <option value="Floette">
# <option value="Florges">
# <option value="Skiddo">
# <option value="Gogoat">
# <option value="Pancham">
# <option value="Pangoro">
# <option value="Furfrou">
# <option value="Espurr">
# <option value="Meowstic">
# <option value="Honedge">
# <option value="Doublade">
# <option value="Aegislash">
# <option value="Spritzee">
# <option value="Aromatisse">
# <option value="Swirlix">
# <option value="Slurpuff">
# <option value="Inkay">
# <option value="Malamar">
# <option value="Binacle">
# <option value="Barbaracle">
# <option value="Skrelp">
# <option value="Dragalge">
# <option value="Clauncher">
# <option value="Clawitzer">
# <option value="Helioptile">
# <option value="Heliolisk">
# <option value="Tyrunt">
# <option value="Tyrantrum">
# <option value="Amaura">
# <option value="Aurorus">
# <option value="Sylveon">
# <option value="Hawlucha">
# <option value="Dedenne">
# <option value="Carbink">
# <option value="Goomy">
# <option value="Sliggoo">
# <option value="Goodra">
# <option value="Klefki">
# <option value="Phantump">
# <option value="Trevenant">
# <option value="Pumpkaboo">
# <option value="Gourgeist">
# <option value="Bergmite">
# <option value="Avalugg">
# <option value="Noibat">
# <option value="Noivern">
# <option value="Xerneas">
# <option value="Yveltal">
# <option value="Zygarde">
# <option value="Diancie">
# <option value="HoopaHoopa">
# <option value="Volcanion">

# %%
import os

for filename in os.listdir():
    
    new_name = re.sub(" ", '', filename)
    print(new_name)
    #os.rename("tutorialsdir","tutorialsdirectory")
# Out:
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
