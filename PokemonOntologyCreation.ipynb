# %% [markdown]
# # Pokémon Battle Ontology Initialization
#
# ### Made by Colin Bouwmeester, Jonas Heller and Musa Karim
#
# #### Make sure to have the provided "Pokemon.csv" file in the same directory as this .ipynb file.
# #### Be sure to have installed all the imported modules, running 'pip install modulename'. The used modules are: 'SPARQLWrapper', 'pandas' and 'urllib.parse'
#
#
#
#
# #### If you run every cell, a Turtle file named "Pokemon.ttl" should appear in your directory. Be mindfull of the fact that this file is not reasoned over yet and this still has to happen in, for instance, Protégé.

# %%
#module imports
from rdflib import Graph, RDF, Namespace, Literal, URIRef
from SPARQLWrapper import SPARQLWrapper, JSON
import pandas as pd
import urllib.parse

# %%
#import csv, define types and other data
pokemon = pd.read_csv("Pokemon.csv")

normal = "Normal"
fighting = "Fighting"
flying = "Flying"
poison = "Poison"
ground = "Ground"
rock = "Rock"
bug = "Bug"
ghost = "Ghost"
steel = "Steel"
fire = "Fire"
water = "Water"
grass = "Grass"
electric = "Electric"
psychic = "Psychic"
ice = "Ice"
dragon = "Dragon"
dark = "Dark"
fairy = "Fairy"

totallist = [normal, fighting, flying, poison, ground, rock, bug, ghost, steel, fire, water, grass,
             electric, psychic, ice, dragon, dark, fairy]

weak_dict = {normal:[rock,steel], 
            fighting:[flying,poison,bug,psychic,fairy],
            flying:[rock,steel,electric],
            poison:[poison,ground,rock,ghost],
            ground:[bug,grass],
            rock:[fighting,ground,steel],
            bug:[fighting,flying,poison,ghost,steel,fire,fairy],
            ghost:[dark],
            steel:[steel,fire,water],
            fire:[rock,fire,water,dragon],
            water:[water,grass,dragon],
            grass:[flying,poison,bug,steel,fire,grass,dragon],
            electric:[grass,electric,dragon],
            psychic:[steel,psychic],
            ice:[steel,fire,water,ice],
            dragon:[steel],
            dark:[fighting,dark,fairy],
            fairy:[poison,steel,fire]
            }


ineffective_dict = {normal:[ghost],
                   fighting:[ghost],
                   flying:[],
                   poison:[steel],
                   ground:[flying],
                   rock:[],
                   bug:[],
                   ghost:[normal],
                   steel:[],
                   fire:[],
                   water:[],
                   grass:[],
                   electric:[ground],
                   psychic:[dark],
                   ice:[],
                   dragon:[fairy],
                   dark:[],
                   fairy:[]}


strong_dict = {normal:[],
                 fighting:[normal,rock,steel,ice,dark],
                 flying:[fighting,bug,grass],
                 poison:[grass,fairy],
                 ground:[poison,rock,steel,fire,electric],
                 rock:[flying,bug,fire,ice],
                 bug:[grass,psychic,dark],
                 ghost:[ghost,psychic],
                 steel:[rock,ice,fairy],
                 fire:[bug,steel,grass,ice],
                 water:[ground,rock,fire],
                 grass:[ground,rock,water],
                 electric:[flying,water],
                 psychic:[fighting,poison],
                 ice:[flying,ground,grass,dragon],
                 dragon:[dragon],
                 dark:[ghost,psychic],
                 fairy:[fighting,dragon,dark]}

gen_list = ['Kanto', 'Johto', 'Hoenn', 'Sinnoh', 'Unova', 'Kalos']

trainer_dict = {'Ash': ['Pikachu', 'Charizard'], 'Brock' : ['Onix'],
                'Misty' : ['Togepi', 'Psyduck'], 'Gary' : ['Blastoise', 'Arcanine']}

pokeball_dict = {'Ash' : ['Pokéball', 'Greatball', 'Ultraball'], 'Brock' : ['Pokéball', 'Greatball'],
                 'Misty' : ['Pokéball'], 'Gary' : ['Greatball', 'Ultraball']}


neutral_dict = {typing: [x for x in totallist if x not in (weak_dict[typing] + strong_dict[typing]
                                                           + ineffective_dict[typing])] for typing in totallist}

# %%
#Initialize graph and namespaces
pokegraph = Graph()
DBR = Namespace('http://dbpedia.org/resource/')
DBO = Namespace('http://dbpedia.org/ontology/')
RDFS = Namespace('http://www.w3.org/2000/01/rdf-schema#')
DUL = Namespace('http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#')
POK = Namespace('http://www.example.org/pokemon/')
BIBO = Namespace('http://purl.org/ontology/bibo/')
OWL = Namespace("http://www.w3.org/2002/07/owl#")
FOAF = Namespace("http://xmlns.com/foaf/0.1/")
PEXT = Namespace("http://www.ontotext.com/proton/protonext#")

pokegraph.bind('foaf', FOAF)
pokegraph.bind('pok',POK)
pokegraph.bind('dbr',DBR)
pokegraph.bind('dbo',DBO)
pokegraph.bind('rdfs',RDFS)
pokegraph.bind('dul',DUL)
pokegraph.bind('bibo',BIBO)
pokegraph.bind('owl',OWL)
pokegraph.bind('pext',PEXT)

#Add classes
pokegraph.add((POK.Pokémon, RDF.type, RDFS.Class))
pokegraph.add((POK.Region, RDF.type, RDFS.Class))
pokegraph.add((POK.Typing, RDF.type, RDFS.Class))
pokegraph.add((POK.FantasyWorld, RDF.type, RDFS.Class))
pokegraph.add((POK.PokémonWorld, RDF.type, RDFS.Class))
pokegraph.add((POK.Creature, RDF.type, RDFS.Class))
pokegraph.add((POK.Trainer, RDF.type, RDFS.Class))
pokegraph.add((POK.Item, RDF.type, RDFS.Class))
pokegraph.add((POK.Pokéball, RDF.type, RDFS.Class))
pokegraph.add((POK.Image, RDF.type, RDFS.Class))
pokegraph.add((POK.Sound, RDF.type, RDFS.Class))
pokegraph.add((PEXT.Human, RDF.type, RDFS.Class))
pokegraph.add((PEXT.Mammal, RDF.type, RDFS.Class))
pokegraph.add((POK.RealWorld, RDF.type, RDFS.Class))
pokegraph.add((POK.Media, RDF.type, RDFS.Class))

#Setup class hierarchy

pokegraph.add((POK.Media, RDFS.subClassOf, POK.RealWorld))
pokegraph.add((POK.Sound, RDFS.subClassOf, POK.Media))
pokegraph.add((POK.Image, RDFS.subClassOf, POK.Media))
pokegraph.add((POK.PokémonWorld, RDFS.subClassOf, POK.FantasyWorld))
pokegraph.add((POK.Creature, RDFS.subClassOf, POK.PokémonWorld))
pokegraph.add((PEXT.Mammal, RDFS.subClassOf, POK.Creature))
pokegraph.add((PEXT.Human, RDFS.subClassOf, PEXT.Mammal))
pokegraph.add((POK.Trainer, RDFS.subClassOf, PEXT.Human))
pokegraph.add((POK.Pokémon, RDFS.subClassOf, POK.Creature))
pokegraph.add((POK.Item, RDFS.subClassOf, POK.PokémonWorld))
pokegraph.add((POK.Pokéball, RDFS.subClassOf, POK.Item))
pokegraph.add((POK.Region, RDFS.subClassOf, POK.PokémonWorld))
pokegraph.add((POK.Typing, RDFS.subClassOf, POK.PokémonWorld))

#Load Pokémon info from csv and other places
for i in range(len(list(pokemon['Name']))):
    subject = URIRef("http://www.example.org/pokemon/" + pokemon['Name'][i].replace(' ', '_').replace('.', '').replace('\'',''))

    #Load name, region and first type
    pokegraph.add((subject, FOAF.name, Literal(pokemon['Name'][i].replace(' ', '_').replace('.', '').replace('\'',''))))
    pokegraph.add((subject, POK.hasRegion, URIRef("http://www.example.org/pokemon/" + gen_list[int(pokemon['Generation'][i])-1])))
    pokegraph.add((subject, POK.hasType, URIRef("http://www.example.org/pokemon/" + pokemon['Type 1'][i])))
    pokegraph.add((subject, POK.stats, URIRef("http://www.example.org/pokemon/" + str(pokemon['Total'][i]))))
    
    
    #Load type 2 (optional since some Pokémon only have one type)
    if type(pokemon['Type 2'][i]) is not float:
        pokegraph.add((subject, POK.hasType, URIRef("http://www.example.org/pokemon/" + pokemon['Type 2'][i])))
        
        
    #Load Image
    ID = str(i+1)
    image = URIRef("https://pokeres.bastionbot.org/images/pokemon/" + ID + ".png")
    pokegraph.add((subject, BIBO.Image, image))
    
    #Load Sound
    if i < 9:
        encode = URIRef(urllib.parse.quote('sound/00' + str(i+1) + '-' + pokemon['Name'][i].replace(' ', '_').replace('.', '').replace('\'','') + '.wav'))
        pokegraph.add((subject, BIBO.AudioDocument, encode))
    elif i < 99:
        encode = URIRef(urllib.parse.quote('sound/0' + str(i+1) + '-' + pokemon['Name'][i].replace(' ', '_').replace('.', '').replace('\'','') + '.wav'))
        pokegraph.add((subject, BIBO.AudioDocument, encode))
    else:
        encode = URIRef(urllib.parse.quote('sound/' + str(i+1) + '-' + pokemon['Name'][i].replace(' ', '_').replace('.', '').replace('\'','') + '.wav'))
        pokegraph.add((subject, BIBO.AudioDocument, encode))
        
#Load Trainer Pokéballs and Pokémon
for trainer in trainer_dict:
    trainerURI = URIRef("http://www.example.org/pokemon/" + trainer)
    
    for balltype in pokeball_dict[trainer]:
        pokeball = URIRef('http://www.example.org/pokemon/' + balltype)
        pokegraph.add((trainerURI, POK.hasItem, pokeball))
    
    for pok in trainer_dict[trainer]:
        subject = URIRef("http://www.example.org/pokemon/" + pok.replace(' ', '_').replace('.', ''))      
        pokegraph.add((trainerURI, POK.hasPokemon, subject))
        
#Load type advantages
for typing in totallist:
    typingURI = URIRef("http://www.example.org/pokemon/" + typing)
    
    for strong in strong_dict[typing]:
        pokegraph.add((typingURI, POK.StrongTo, URIRef("http://www.example.org/pokemon/" + strong)))
    for weak in weak_dict[typing]:
        pokegraph.add((typingURI, POK.WeakTo, URIRef("http://www.example.org/pokemon/" + weak)))
    for resist in ineffective_dict[typing]:
        pokegraph.add((typingURI, POK.WeakTo, URIRef("http://www.example.org/pokemon/" + resist)))
    for neutral in neutral_dict[typing]:
        pokegraph.add((typingURI, POK.NeutralTo, URIRef("http://www.example.org/pokemon/" + neutral)))
        
#Define object properties    
pokegraph.add((POK.hasType, RDF.type, OWL.ObjectProperty))    
pokegraph.add((POK.hasRegion, RDF.type, OWL.ObjectProperty))
pokegraph.add((FOAF.name, RDF.type, OWL.ObjectProperty))  
pokegraph.add((BIBO.Image, RDF.type, OWL.ObjectProperty))
pokegraph.add((BIBO.AudioDocument, RDF.type, OWL.ObjectProperty))
pokegraph.add((POK.hasPokemon, RDF.type, OWL.ObjectProperty))
pokegraph.add((POK.hasItem, RDF.type, OWL.ObjectProperty))
pokegraph.add((POK.StrongTo, RDF.type, OWL.ObjectProperty))
pokegraph.add((POK.WeakTo, RDF.type, OWL.ObjectProperty))
pokegraph.add((POK.NeutralTo, RDF.type, OWL.ObjectProperty))
pokegraph.add((POK.stats, RDF.type, OWL.ObjectProperty))


#Define domains and ranges
pokegraph.add((POK.hasType, RDFS.domain, POK.Pokémon))
pokegraph.add((POK.hasType, RDFS.range, POK.Typing))
pokegraph.add((POK.hasRegion, RDFS.range, POK.Region))
pokegraph.add((BIBO.Image, RDFS.range, POK.Image))
pokegraph.add((BIBO.AudioDocument, RDFS.range, POK.Sound))
pokegraph.add((POK.hasPokemon, RDFS.domain, POK.Trainer))
pokegraph.add((POK.hasItem, RDFS.range, POK.Pokéball))

#Print output to verify    
print(pokegraph.serialize(format='turtle').decode("utf-8"))

#Write ontology tot turtlefile
pokegraph.serialize(destination="Pokemon.ttl", format='turtle')
# Out:
# @prefix bibo: <http://purl.org/ontology/bibo/> .
# @prefix dbo: <http://dbpedia.org/ontology/> .
# @prefix dbr: <http://dbpedia.org/resource/> .
# @prefix dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#> .
# @prefix foaf: <http://xmlns.com/foaf/0.1/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix pext: <http://www.ontotext.com/proton/protonext#> .
# @prefix pok: <http://www.example.org/pokemon/> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xml: <http://www.w3.org/XML/1998/namespace> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# pok:Creature a rdfs:Class ;
#     rdfs:subClassOf pok:PokémonWorld .
#
# pok:FantasyWorld a rdfs:Class .
#
# pok:Image a rdfs:Class ;
#     rdfs:subClassOf pok:Media .
#
# pok:Item a rdfs:Class ;
#     rdfs:subClassOf pok:PokémonWorld .
#
# pok:Media a rdfs:Class ;
#     rdfs:subClassOf pok:RealWorld .
#
# pok:Pokéball a rdfs:Class ;
#     rdfs:subClassOf pok:Item .
#
# pok:Pokémon a rdfs:Class ;
#     rdfs:subClassOf pok:Creature .
#
# pok:PokémonWorld a rdfs:Class ;
#     rdfs:subClassOf pok:FantasyWorld .
#
# pok:RealWorld a rdfs:Class .
#
# pok:Region a rdfs:Class ;
#     rdfs:subClassOf pok:PokémonWorld .
#
# pok:Sound a rdfs:Class ;
#     rdfs:subClassOf pok:Media .
#
# pok:Trainer a rdfs:Class ;
#     rdfs:subClassOf pext:Human .
#
# pok:Typing a rdfs:Class ;
#     rdfs:subClassOf pok:PokémonWorld .
#
# pext:Human a rdfs:Class ;
#     rdfs:subClassOf pext:Mammal .
#
# pext:Mammal a rdfs:Class ;
#     rdfs:subClassOf pok:Creature .
#
# bibo:AudioDocument a owl:ObjectProperty ;
#     rdfs:range pok:Sound .
#
# bibo:Image a owl:ObjectProperty ;
#     rdfs:range pok:Image .
#
# pok:Abomasnow bibo:AudioDocument <sound/460-Abomasnow.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/460.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Grass,
#         pok:Ice ;
#     pok:stats <http://www.example.org/pokemon/494> ;
#     foaf:name "Abomasnow" .
#
# pok:Abra bibo:AudioDocument <sound/063-Abra.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/63.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Psychic ;
#     pok:stats <http://www.example.org/pokemon/310> ;
#     foaf:name "Abra" .
#
# pok:Absol bibo:AudioDocument <sound/359-Absol.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/359.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Dark ;
#     pok:stats <http://www.example.org/pokemon/465> ;
#     foaf:name "Absol" .
#
# pok:Accelgor bibo:AudioDocument <sound/617-Accelgor.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/617.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Bug ;
#     pok:stats <http://www.example.org/pokemon/495> ;
#     foaf:name "Accelgor" .
#
# pok:Aegislash bibo:AudioDocument <sound/681-Aegislash.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/681.png> ;
#     pok:hasRegion pok:Kalos ;
#     pok:hasType pok:Ghost,
#         pok:Steel ;
#     pok:stats <http://www.example.org/pokemon/520> ;
#     foaf:name "Aegislash" .
#
# pok:Aerodactyl bibo:AudioDocument <sound/142-Aerodactyl.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/142.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Flying,
#         pok:Rock ;
#     pok:stats <http://www.example.org/pokemon/515> ;
#     foaf:name "Aerodactyl" .
#
# pok:Aggron bibo:AudioDocument <sound/306-Aggron.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/306.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Rock,
#         pok:Steel ;
#     pok:stats <http://www.example.org/pokemon/530> ;
#     foaf:name "Aggron" .
#
# pok:Aipom bibo:AudioDocument <sound/190-Aipom.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/190.png> ;
#     pok:hasRegion pok:Johto ;
#     pok:hasType pok:Normal ;
#     pok:stats <http://www.example.org/pokemon/360> ;
#     foaf:name "Aipom" .
#
# pok:Alakazam bibo:AudioDocument <sound/065-Alakazam.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/65.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Psychic ;
#     pok:stats <http://www.example.org/pokemon/500> ;
#     foaf:name "Alakazam" .
#
# pok:Alomomola bibo:AudioDocument <sound/594-Alomomola.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/594.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Water ;
#     pok:stats <http://www.example.org/pokemon/470> ;
#     foaf:name "Alomomola" .
#
# pok:Altaria bibo:AudioDocument <sound/334-Altaria.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/334.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Dragon,
#         pok:Flying ;
#     pok:stats <http://www.example.org/pokemon/490> ;
#     foaf:name "Altaria" .
#
# pok:Amaura bibo:AudioDocument <sound/698-Amaura.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/698.png> ;
#     pok:hasRegion pok:Kalos ;
#     pok:hasType pok:Ice,
#         pok:Rock ;
#     pok:stats <http://www.example.org/pokemon/362> ;
#     foaf:name "Amaura" .
#
# pok:Ambipom bibo:AudioDocument <sound/424-Ambipom.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/424.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Normal ;
#     pok:stats <http://www.example.org/pokemon/482> ;
#     foaf:name "Ambipom" .
#
# pok:Amoonguss bibo:AudioDocument <sound/591-Amoonguss.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/591.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Grass,
#         pok:Poison ;
#     pok:stats <http://www.example.org/pokemon/464> ;
#     foaf:name "Amoonguss" .
#
# pok:Ampharos bibo:AudioDocument <sound/181-Ampharos.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/181.png> ;
#     pok:hasRegion pok:Johto ;
#     pok:hasType pok:Electric ;
#     pok:stats <http://www.example.org/pokemon/510> ;
#     foaf:name "Ampharos" .
#
# pok:Anorith bibo:AudioDocument <sound/347-Anorith.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/347.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Bug,
#         pok:Rock ;
#     pok:stats <http://www.example.org/pokemon/355> ;
#     foaf:name "Anorith" .
#
# pok:Arbok bibo:AudioDocument <sound/024-Arbok.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/24.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Poison ;
#     pok:stats <http://www.example.org/pokemon/438> ;
#     foaf:name "Arbok" .
#
# pok:Arceus bibo:AudioDocument <sound/493-Arceus.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/493.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Normal ;
#     pok:stats <http://www.example.org/pokemon/720> ;
#     foaf:name "Arceus" .
#
# pok:Archen bibo:AudioDocument <sound/566-Archen.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/566.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Flying,
#         pok:Rock ;
#     pok:stats <http://www.example.org/pokemon/401> ;
#     foaf:name "Archen" .
#
# pok:Archeops bibo:AudioDocument <sound/567-Archeops.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/567.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Flying,
#         pok:Rock ;
#     pok:stats <http://www.example.org/pokemon/567> ;
#     foaf:name "Archeops" .
#
# pok:Ariados bibo:AudioDocument <sound/168-Ariados.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/168.png> ;
#     pok:hasRegion pok:Johto ;
#     pok:hasType pok:Bug,
#         pok:Poison ;
#     pok:stats <http://www.example.org/pokemon/390> ;
#     foaf:name "Ariados" .
#
# pok:Armaldo bibo:AudioDocument <sound/348-Armaldo.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/348.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Bug,
#         pok:Rock ;
#     pok:stats <http://www.example.org/pokemon/495> ;
#     foaf:name "Armaldo" .
#
# pok:Aromatisse bibo:AudioDocument <sound/683-Aromatisse.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/683.png> ;
#     pok:hasRegion pok:Kalos ;
#     pok:hasType pok:Fairy ;
#     pok:stats <http://www.example.org/pokemon/462> ;
#     foaf:name "Aromatisse" .
#
# pok:Aron bibo:AudioDocument <sound/304-Aron.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/304.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Rock,
#         pok:Steel ;
#     pok:stats <http://www.example.org/pokemon/330> ;
#     foaf:name "Aron" .
#
# pok:Articuno bibo:AudioDocument <sound/144-Articuno.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/144.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Flying,
#         pok:Ice ;
#     pok:stats <http://www.example.org/pokemon/580> ;
#     foaf:name "Articuno" .
#
# pok:Ash pok:hasItem pok:Greatball,
#         pok:Pokéball,
#         pok:Ultraball ;
#     pok:hasPokemon pok:Charizard,
#         pok:Pikachu .
#
# pok:Audino bibo:AudioDocument <sound/531-Audino.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/531.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Normal ;
#     pok:stats <http://www.example.org/pokemon/445> ;
#     foaf:name "Audino" .
#
# pok:Aurorus bibo:AudioDocument <sound/699-Aurorus.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/699.png> ;
#     pok:hasRegion pok:Kalos ;
#     pok:hasType pok:Ice,
#         pok:Rock ;
#     pok:stats <http://www.example.org/pokemon/521> ;
#     foaf:name "Aurorus" .
#
# pok:Avalugg bibo:AudioDocument <sound/713-Avalugg.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/713.png> ;
#     pok:hasRegion pok:Kalos ;
#     pok:hasType pok:Ice ;
#     pok:stats <http://www.example.org/pokemon/514> ;
#     foaf:name "Avalugg" .
#
# pok:Axew bibo:AudioDocument <sound/610-Axew.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/610.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Dragon ;
#     pok:stats <http://www.example.org/pokemon/320> ;
#     foaf:name "Axew" .
#
# pok:Azelf bibo:AudioDocument <sound/482-Azelf.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/482.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Psychic ;
#     pok:stats <http://www.example.org/pokemon/580> ;
#     foaf:name "Azelf" .
#
# pok:Azumarill bibo:AudioDocument <sound/184-Azumarill.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/184.png> ;
#     pok:hasRegion pok:Johto ;
#     pok:hasType pok:Fairy,
#         pok:Water ;
#     pok:stats <http://www.example.org/pokemon/420> ;
#     foaf:name "Azumarill" .
#
# pok:Azurill bibo:AudioDocument <sound/298-Azurill.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/298.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Fairy,
#         pok:Normal ;
#     pok:stats <http://www.example.org/pokemon/190> ;
#     foaf:name "Azurill" .
#
# pok:Bagon bibo:AudioDocument <sound/371-Bagon.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/371.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Dragon ;
#     pok:stats <http://www.example.org/pokemon/300> ;
#     foaf:name "Bagon" .
#
# pok:Baltoy bibo:AudioDocument <sound/343-Baltoy.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/343.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Ground,
#         pok:Psychic ;
#     pok:stats <http://www.example.org/pokemon/300> ;
#     foaf:name "Baltoy" .
#
# pok:Banette bibo:AudioDocument <sound/354-Banette.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/354.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Ghost ;
#     pok:stats <http://www.example.org/pokemon/455> ;
#     foaf:name "Banette" .
#
# pok:Barbaracle bibo:AudioDocument <sound/689-Barbaracle.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/689.png> ;
#     pok:hasRegion pok:Kalos ;
#     pok:hasType pok:Rock,
#         pok:Water ;
#     pok:stats <http://www.example.org/pokemon/500> ;
#     foaf:name "Barbaracle" .
#
# pok:Barboach bibo:AudioDocument <sound/339-Barboach.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/339.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Ground,
#         pok:Water ;
#     pok:stats <http://www.example.org/pokemon/288> ;
#     foaf:name "Barboach" .
#
# pok:Basculin bibo:AudioDocument <sound/550-Basculin.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/550.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Water ;
#     pok:stats <http://www.example.org/pokemon/460> ;
#     foaf:name "Basculin" .
#
# pok:Bastiodon bibo:AudioDocument <sound/411-Bastiodon.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/411.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Rock,
#         pok:Steel ;
#     pok:stats <http://www.example.org/pokemon/495> ;
#     foaf:name "Bastiodon" .
#
# pok:Bayleef bibo:AudioDocument <sound/153-Bayleef.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/153.png> ;
#     pok:hasRegion pok:Johto ;
#     pok:hasType pok:Grass ;
#     pok:stats <http://www.example.org/pokemon/405> ;
#     foaf:name "Bayleef" .
#
# pok:Beartic bibo:AudioDocument <sound/614-Beartic.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/614.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Ice ;
#     pok:stats <http://www.example.org/pokemon/485> ;
#     foaf:name "Beartic" .
#
# pok:Beautifly bibo:AudioDocument <sound/267-Beautifly.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/267.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Bug,
#         pok:Flying ;
#     pok:stats <http://www.example.org/pokemon/395> ;
#     foaf:name "Beautifly" .
#
# pok:Beedrill bibo:AudioDocument <sound/015-Beedrill.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/15.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Bug,
#         pok:Poison ;
#     pok:stats <http://www.example.org/pokemon/395> ;
#     foaf:name "Beedrill" .
#
# pok:Beheeyem bibo:AudioDocument <sound/606-Beheeyem.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/606.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Psychic ;
#     pok:stats <http://www.example.org/pokemon/485> ;
#     foaf:name "Beheeyem" .
#
# pok:Beldum bibo:AudioDocument <sound/374-Beldum.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/374.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Psychic,
#         pok:Steel ;
#     pok:stats <http://www.example.org/pokemon/300> ;
#     foaf:name "Beldum" .
#
# pok:Bellossom bibo:AudioDocument <sound/182-Bellossom.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/182.png> ;
#     pok:hasRegion pok:Johto ;
#     pok:hasType pok:Grass ;
#     pok:stats <http://www.example.org/pokemon/490> ;
#     foaf:name "Bellossom" .
#
# pok:Bellsprout bibo:AudioDocument <sound/069-Bellsprout.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/69.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Grass,
#         pok:Poison ;
#     pok:stats <http://www.example.org/pokemon/300> ;
#     foaf:name "Bellsprout" .
#
# pok:Bergmite bibo:AudioDocument <sound/712-Bergmite.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/712.png> ;
#     pok:hasRegion pok:Kalos ;
#     pok:hasType pok:Ice ;
#     pok:stats <http://www.example.org/pokemon/304> ;
#     foaf:name "Bergmite" .
#
# pok:Bibarel bibo:AudioDocument <sound/400-Bibarel.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/400.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Normal,
#         pok:Water ;
#     pok:stats <http://www.example.org/pokemon/410> ;
#     foaf:name "Bibarel" .
#
# pok:Bidoof bibo:AudioDocument <sound/399-Bidoof.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/399.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Normal ;
#     pok:stats <http://www.example.org/pokemon/250> ;
#     foaf:name "Bidoof" .
#
# pok:Binacle bibo:AudioDocument <sound/688-Binacle.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/688.png> ;
#     pok:hasRegion pok:Kalos ;
#     pok:hasType pok:Rock,
#         pok:Water ;
#     pok:stats <http://www.example.org/pokemon/306> ;
#     foaf:name "Binacle" .
#
# pok:Bisharp bibo:AudioDocument <sound/625-Bisharp.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/625.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Dark,
#         pok:Steel ;
#     pok:stats <http://www.example.org/pokemon/490> ;
#     foaf:name "Bisharp" .
#
# pok:Blaziken bibo:AudioDocument <sound/257-Blaziken.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/257.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Fighting,
#         pok:Fire ;
#     pok:stats <http://www.example.org/pokemon/530> ;
#     foaf:name "Blaziken" .
#
# pok:Blissey bibo:AudioDocument <sound/242-Blissey.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/242.png> ;
#     pok:hasRegion pok:Johto ;
#     pok:hasType pok:Normal ;
#     pok:stats <http://www.example.org/pokemon/540> ;
#     foaf:name "Blissey" .
#
# pok:Blitzle bibo:AudioDocument <sound/522-Blitzle.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/522.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Electric ;
#     pok:stats <http://www.example.org/pokemon/295> ;
#     foaf:name "Blitzle" .
#
# pok:Boldore bibo:AudioDocument <sound/525-Boldore.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/525.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Rock ;
#     pok:stats <http://www.example.org/pokemon/390> ;
#     foaf:name "Boldore" .
#
# pok:Bonsly bibo:AudioDocument <sound/438-Bonsly.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/438.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Rock ;
#     pok:stats <http://www.example.org/pokemon/290> ;
#     foaf:name "Bonsly" .
#
# pok:Bouffalant bibo:AudioDocument <sound/626-Bouffalant.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/626.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Normal ;
#     pok:stats <http://www.example.org/pokemon/490> ;
#     foaf:name "Bouffalant" .
#
# pok:Braixen bibo:AudioDocument <sound/654-Braixen.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/654.png> ;
#     pok:hasRegion pok:Kalos ;
#     pok:hasType pok:Fire ;
#     pok:stats <http://www.example.org/pokemon/409> ;
#     foaf:name "Braixen" .
#
# pok:Braviary bibo:AudioDocument <sound/628-Braviary.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/628.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Flying,
#         pok:Normal ;
#     pok:stats <http://www.example.org/pokemon/510> ;
#     foaf:name "Braviary" .
#
# pok:Breloom bibo:AudioDocument <sound/286-Breloom.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/286.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Fighting,
#         pok:Grass ;
#     pok:stats <http://www.example.org/pokemon/460> ;
#     foaf:name "Breloom" .
#
# pok:Brock pok:hasItem pok:Greatball,
#         pok:Pokéball ;
#     pok:hasPokemon pok:Onix .
#
# pok:Bronzong bibo:AudioDocument <sound/437-Bronzong.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/437.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Psychic,
#         pok:Steel ;
#     pok:stats <http://www.example.org/pokemon/500> ;
#     foaf:name "Bronzong" .
#
# pok:Bronzor bibo:AudioDocument <sound/436-Bronzor.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/436.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Psychic,
#         pok:Steel ;
#     pok:stats <http://www.example.org/pokemon/300> ;
#     foaf:name "Bronzor" .
#
# pok:Budew bibo:AudioDocument <sound/406-Budew.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/406.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Grass,
#         pok:Poison ;
#     pok:stats <http://www.example.org/pokemon/280> ;
#     foaf:name "Budew" .
#
# pok:Buizel bibo:AudioDocument <sound/418-Buizel.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/418.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Water ;
#     pok:stats <http://www.example.org/pokemon/330> ;
#     foaf:name "Buizel" .
#
# pok:Bulbasaur bibo:AudioDocument <sound/001-Bulbasaur.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/1.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Grass,
#         pok:Poison ;
#     pok:stats <http://www.example.org/pokemon/318> ;
#     foaf:name "Bulbasaur" .
#
# pok:Buneary bibo:AudioDocument <sound/427-Buneary.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/427.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Normal ;
#     pok:stats <http://www.example.org/pokemon/350> ;
#     foaf:name "Buneary" .
#
# pok:Bunnelby bibo:AudioDocument <sound/659-Bunnelby.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/659.png> ;
#     pok:hasRegion pok:Kalos ;
#     pok:hasType pok:Normal ;
#     pok:stats <http://www.example.org/pokemon/237> ;
#     foaf:name "Bunnelby" .
#
# pok:Burmy bibo:AudioDocument <sound/412-Burmy.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/412.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Bug ;
#     pok:stats <http://www.example.org/pokemon/224> ;
#     foaf:name "Burmy" .
#
# pok:Butterfree bibo:AudioDocument <sound/012-Butterfree.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/12.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Bug,
#         pok:Flying ;
#     pok:stats <http://www.example.org/pokemon/395> ;
#     foaf:name "Butterfree" .
#
# pok:Cacnea bibo:AudioDocument <sound/331-Cacnea.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/331.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Grass ;
#     pok:stats <http://www.example.org/pokemon/335> ;
#     foaf:name "Cacnea" .
#
# pok:Cacturne bibo:AudioDocument <sound/332-Cacturne.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/332.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Dark,
#         pok:Grass ;
#     pok:stats <http://www.example.org/pokemon/475> ;
#     foaf:name "Cacturne" .
#
# pok:Camerupt bibo:AudioDocument <sound/323-Camerupt.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/323.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Fire,
#         pok:Ground ;
#     pok:stats <http://www.example.org/pokemon/460> ;
#     foaf:name "Camerupt" .
#
# pok:Carbink bibo:AudioDocument <sound/703-Carbink.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/703.png> ;
#     pok:hasRegion pok:Kalos ;
#     pok:hasType pok:Fairy,
#         pok:Rock ;
#     pok:stats <http://www.example.org/pokemon/500> ;
#     foaf:name "Carbink" .
#
# pok:Carnivine bibo:AudioDocument <sound/455-Carnivine.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/455.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Grass ;
#     pok:stats <http://www.example.org/pokemon/454> ;
#     foaf:name "Carnivine" .
#
# pok:Carracosta bibo:AudioDocument <sound/565-Carracosta.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/565.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Rock,
#         pok:Water ;
#     pok:stats <http://www.example.org/pokemon/495> ;
#     foaf:name "Carracosta" .
#
# pok:Carvanha bibo:AudioDocument <sound/318-Carvanha.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/318.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Dark,
#         pok:Water ;
#     pok:stats <http://www.example.org/pokemon/305> ;
#     foaf:name "Carvanha" .
#
# pok:Cascoon bibo:AudioDocument <sound/268-Cascoon.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/268.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Bug ;
#     pok:stats <http://www.example.org/pokemon/205> ;
#     foaf:name "Cascoon" .
#
# pok:Castform bibo:AudioDocument <sound/351-Castform.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/351.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Normal ;
#     pok:stats <http://www.example.org/pokemon/420> ;
#     foaf:name "Castform" .
#
# pok:Caterpie bibo:AudioDocument <sound/010-Caterpie.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/10.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Bug ;
#     pok:stats <http://www.example.org/pokemon/195> ;
#     foaf:name "Caterpie" .
#
# pok:Celebi bibo:AudioDocument <sound/251-Celebi.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/251.png> ;
#     pok:hasRegion pok:Johto ;
#     pok:hasType pok:Grass,
#         pok:Psychic ;
#     pok:stats <http://www.example.org/pokemon/600> ;
#     foaf:name "Celebi" .
#
# pok:Chandelure bibo:AudioDocument <sound/609-Chandelure.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/609.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Fire,
#         pok:Ghost ;
#     pok:stats <http://www.example.org/pokemon/520> ;
#     foaf:name "Chandelure" .
#
# pok:Chansey bibo:AudioDocument <sound/113-Chansey.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/113.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Normal ;
#     pok:stats <http://www.example.org/pokemon/450> ;
#     foaf:name "Chansey" .
#
# pok:Charmander bibo:AudioDocument <sound/004-Charmander.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/4.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Fire ;
#     pok:stats <http://www.example.org/pokemon/309> ;
#     foaf:name "Charmander" .
#
# pok:Charmeleon bibo:AudioDocument <sound/005-Charmeleon.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/5.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Fire ;
#     pok:stats <http://www.example.org/pokemon/405> ;
#     foaf:name "Charmeleon" .
#
# pok:Chatot bibo:AudioDocument <sound/441-Chatot.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/441.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Flying,
#         pok:Normal ;
#     pok:stats <http://www.example.org/pokemon/411> ;
#     foaf:name "Chatot" .
#
# pok:Cherrim bibo:AudioDocument <sound/421-Cherrim.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/421.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Grass ;
#     pok:stats <http://www.example.org/pokemon/450> ;
#     foaf:name "Cherrim" .
#
# pok:Cherubi bibo:AudioDocument <sound/420-Cherubi.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/420.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Grass ;
#     pok:stats <http://www.example.org/pokemon/275> ;
#     foaf:name "Cherubi" .
#
# pok:Chesnaught bibo:AudioDocument <sound/652-Chesnaught.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/652.png> ;
#     pok:hasRegion pok:Kalos ;
#     pok:hasType pok:Fighting,
#         pok:Grass ;
#     pok:stats <http://www.example.org/pokemon/530> ;
#     foaf:name "Chesnaught" .
#
# pok:Chespin bibo:AudioDocument <sound/650-Chespin.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/650.png> ;
#     pok:hasRegion pok:Kalos ;
#     pok:hasType pok:Grass ;
#     pok:stats <http://www.example.org/pokemon/313> ;
#     foaf:name "Chespin" .
#
# pok:Chikorita bibo:AudioDocument <sound/152-Chikorita.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/152.png> ;
#     pok:hasRegion pok:Johto ;
#     pok:hasType pok:Grass ;
#     pok:stats <http://www.example.org/pokemon/318> ;
#     foaf:name "Chikorita" .
#
# pok:Chimchar bibo:AudioDocument <sound/390-Chimchar.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/390.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Fire ;
#     pok:stats <http://www.example.org/pokemon/309> ;
#     foaf:name "Chimchar" .
#
# pok:Chimecho bibo:AudioDocument <sound/358-Chimecho.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/358.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Psychic ;
#     pok:stats <http://www.example.org/pokemon/425> ;
#     foaf:name "Chimecho" .
#
# pok:Chinchou bibo:AudioDocument <sound/170-Chinchou.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/170.png> ;
#     pok:hasRegion pok:Johto ;
#     pok:hasType pok:Electric,
#         pok:Water ;
#     pok:stats <http://www.example.org/pokemon/330> ;
#     foaf:name "Chinchou" .
#
# pok:Chingling bibo:AudioDocument <sound/433-Chingling.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/433.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Psychic ;
#     pok:stats <http://www.example.org/pokemon/285> ;
#     foaf:name "Chingling" .
#
# pok:Cinccino bibo:AudioDocument <sound/573-Cinccino.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/573.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Normal ;
#     pok:stats <http://www.example.org/pokemon/470> ;
#     foaf:name "Cinccino" .
#
# pok:Clamperl bibo:AudioDocument <sound/366-Clamperl.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/366.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Water ;
#     pok:stats <http://www.example.org/pokemon/345> ;
#     foaf:name "Clamperl" .
#
# pok:Clauncher bibo:AudioDocument <sound/692-Clauncher.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/692.png> ;
#     pok:hasRegion pok:Kalos ;
#     pok:hasType pok:Water ;
#     pok:stats <http://www.example.org/pokemon/330> ;
#     foaf:name "Clauncher" .
#
# pok:Clawitzer bibo:AudioDocument <sound/693-Clawitzer.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/693.png> ;
#     pok:hasRegion pok:Kalos ;
#     pok:hasType pok:Water ;
#     pok:stats <http://www.example.org/pokemon/500> ;
#     foaf:name "Clawitzer" .
#
# pok:Claydol bibo:AudioDocument <sound/344-Claydol.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/344.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Ground,
#         pok:Psychic ;
#     pok:stats <http://www.example.org/pokemon/500> ;
#     foaf:name "Claydol" .
#
# pok:Clefable bibo:AudioDocument <sound/036-Clefable.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/36.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Fairy ;
#     pok:stats <http://www.example.org/pokemon/483> ;
#     foaf:name "Clefable" .
#
# pok:Clefairy bibo:AudioDocument <sound/035-Clefairy.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/35.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Fairy ;
#     pok:stats <http://www.example.org/pokemon/323> ;
#     foaf:name "Clefairy" .
#
# pok:Cleffa bibo:AudioDocument <sound/173-Cleffa.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/173.png> ;
#     pok:hasRegion pok:Johto ;
#     pok:hasType pok:Fairy ;
#     pok:stats <http://www.example.org/pokemon/218> ;
#     foaf:name "Cleffa" .
#
# pok:Cloyster bibo:AudioDocument <sound/091-Cloyster.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/91.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Ice,
#         pok:Water ;
#     pok:stats <http://www.example.org/pokemon/525> ;
#     foaf:name "Cloyster" .
#
# pok:Cobalion bibo:AudioDocument <sound/638-Cobalion.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/638.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Fighting,
#         pok:Steel ;
#     pok:stats <http://www.example.org/pokemon/580> ;
#     foaf:name "Cobalion" .
#
# pok:Cofagrigus bibo:AudioDocument <sound/563-Cofagrigus.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/563.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Ghost ;
#     pok:stats <http://www.example.org/pokemon/483> ;
#     foaf:name "Cofagrigus" .
#
# pok:Combee bibo:AudioDocument <sound/415-Combee.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/415.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Bug,
#         pok:Flying ;
#     pok:stats <http://www.example.org/pokemon/244> ;
#     foaf:name "Combee" .
#
# pok:Combusken bibo:AudioDocument <sound/256-Combusken.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/256.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Fighting,
#         pok:Fire ;
#     pok:stats <http://www.example.org/pokemon/405> ;
#     foaf:name "Combusken" .
#
# pok:Conkeldurr bibo:AudioDocument <sound/534-Conkeldurr.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/534.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Fighting ;
#     pok:stats <http://www.example.org/pokemon/505> ;
#     foaf:name "Conkeldurr" .
#
# pok:Corphish bibo:AudioDocument <sound/341-Corphish.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/341.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Water ;
#     pok:stats <http://www.example.org/pokemon/308> ;
#     foaf:name "Corphish" .
#
# pok:Corsola bibo:AudioDocument <sound/222-Corsola.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/222.png> ;
#     pok:hasRegion pok:Johto ;
#     pok:hasType pok:Rock,
#         pok:Water ;
#     pok:stats <http://www.example.org/pokemon/380> ;
#     foaf:name "Corsola" .
#
# pok:Cottonee bibo:AudioDocument <sound/546-Cottonee.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/546.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Fairy,
#         pok:Grass ;
#     pok:stats <http://www.example.org/pokemon/280> ;
#     foaf:name "Cottonee" .
#
# pok:Cradily bibo:AudioDocument <sound/346-Cradily.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/346.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Grass,
#         pok:Rock ;
#     pok:stats <http://www.example.org/pokemon/495> ;
#     foaf:name "Cradily" .
#
# pok:Cranidos bibo:AudioDocument <sound/408-Cranidos.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/408.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Rock ;
#     pok:stats <http://www.example.org/pokemon/350> ;
#     foaf:name "Cranidos" .
#
# pok:Crawdaunt bibo:AudioDocument <sound/342-Crawdaunt.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/342.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Dark,
#         pok:Water ;
#     pok:stats <http://www.example.org/pokemon/468> ;
#     foaf:name "Crawdaunt" .
#
# pok:Cresselia bibo:AudioDocument <sound/488-Cresselia.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/488.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Psychic ;
#     pok:stats <http://www.example.org/pokemon/600> ;
#     foaf:name "Cresselia" .
#
# pok:Croagunk bibo:AudioDocument <sound/453-Croagunk.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/453.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Fighting,
#         pok:Poison ;
#     pok:stats <http://www.example.org/pokemon/300> ;
#     foaf:name "Croagunk" .
#
# pok:Crobat bibo:AudioDocument <sound/169-Crobat.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/169.png> ;
#     pok:hasRegion pok:Johto ;
#     pok:hasType pok:Flying,
#         pok:Poison ;
#     pok:stats <http://www.example.org/pokemon/535> ;
#     foaf:name "Crobat" .
#
# pok:Croconaw bibo:AudioDocument <sound/159-Croconaw.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/159.png> ;
#     pok:hasRegion pok:Johto ;
#     pok:hasType pok:Water ;
#     pok:stats <http://www.example.org/pokemon/405> ;
#     foaf:name "Croconaw" .
#
# pok:Crustle bibo:AudioDocument <sound/558-Crustle.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/558.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Bug,
#         pok:Rock ;
#     pok:stats <http://www.example.org/pokemon/475> ;
#     foaf:name "Crustle" .
#
# pok:Cryogonal bibo:AudioDocument <sound/615-Cryogonal.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/615.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Ice ;
#     pok:stats <http://www.example.org/pokemon/485> ;
#     foaf:name "Cryogonal" .
#
# pok:Cubchoo bibo:AudioDocument <sound/613-Cubchoo.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/613.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Ice ;
#     pok:stats <http://www.example.org/pokemon/305> ;
#     foaf:name "Cubchoo" .
#
# pok:Cubone bibo:AudioDocument <sound/104-Cubone.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/104.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Ground ;
#     pok:stats <http://www.example.org/pokemon/320> ;
#     foaf:name "Cubone" .
#
# pok:Cyndaquil bibo:AudioDocument <sound/155-Cyndaquil.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/155.png> ;
#     pok:hasRegion pok:Johto ;
#     pok:hasType pok:Fire ;
#     pok:stats <http://www.example.org/pokemon/309> ;
#     foaf:name "Cyndaquil" .
#
# pok:Darkrai bibo:AudioDocument <sound/491-Darkrai.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/491.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Dark ;
#     pok:stats <http://www.example.org/pokemon/600> ;
#     foaf:name "Darkrai" .
#
# pok:Darmanitan bibo:AudioDocument <sound/555-Darmanitan.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/555.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Fire ;
#     pok:stats <http://www.example.org/pokemon/480> ;
#     foaf:name "Darmanitan" .
#
# pok:Darumaka bibo:AudioDocument <sound/554-Darumaka.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/554.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Fire ;
#     pok:stats <http://www.example.org/pokemon/315> ;
#     foaf:name "Darumaka" .
#
# pok:Dedenne bibo:AudioDocument <sound/702-Dedenne.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/702.png> ;
#     pok:hasRegion pok:Kalos ;
#     pok:hasType pok:Electric,
#         pok:Fairy ;
#     pok:stats <http://www.example.org/pokemon/431> ;
#     foaf:name "Dedenne" .
#
# pok:Deerling bibo:AudioDocument <sound/585-Deerling.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/585.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Grass,
#         pok:Normal ;
#     pok:stats <http://www.example.org/pokemon/335> ;
#     foaf:name "Deerling" .
#
# pok:Deino bibo:AudioDocument <sound/633-Deino.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/633.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Dark,
#         pok:Dragon ;
#     pok:stats <http://www.example.org/pokemon/300> ;
#     foaf:name "Deino" .
#
# pok:Delcatty bibo:AudioDocument <sound/301-Delcatty.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/301.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Normal ;
#     pok:stats <http://www.example.org/pokemon/380> ;
#     foaf:name "Delcatty" .
#
# pok:Delibird bibo:AudioDocument <sound/225-Delibird.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/225.png> ;
#     pok:hasRegion pok:Johto ;
#     pok:hasType pok:Flying,
#         pok:Ice ;
#     pok:stats <http://www.example.org/pokemon/330> ;
#     foaf:name "Delibird" .
#
# pok:Delphox bibo:AudioDocument <sound/655-Delphox.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/655.png> ;
#     pok:hasRegion pok:Kalos ;
#     pok:hasType pok:Fire,
#         pok:Psychic ;
#     pok:stats <http://www.example.org/pokemon/534> ;
#     foaf:name "Delphox" .
#
# pok:Deoxys bibo:AudioDocument <sound/386-Deoxys.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/386.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Psychic ;
#     pok:stats <http://www.example.org/pokemon/600> ;
#     foaf:name "Deoxys" .
#
# pok:Dewgong bibo:AudioDocument <sound/087-Dewgong.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/87.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Ice,
#         pok:Water ;
#     pok:stats <http://www.example.org/pokemon/475> ;
#     foaf:name "Dewgong" .
#
# pok:Dewott bibo:AudioDocument <sound/502-Dewott.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/502.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Water ;
#     pok:stats <http://www.example.org/pokemon/413> ;
#     foaf:name "Dewott" .
#
# pok:Dialga bibo:AudioDocument <sound/483-Dialga.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/483.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Dragon,
#         pok:Steel ;
#     pok:stats <http://www.example.org/pokemon/680> ;
#     foaf:name "Dialga" .
#
# pok:Diancie bibo:AudioDocument <sound/719-Diancie.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/719.png> ;
#     pok:hasRegion pok:Kalos ;
#     pok:hasType pok:Fairy,
#         pok:Rock ;
#     pok:stats <http://www.example.org/pokemon/600> ;
#     foaf:name "Diancie" .
#
# pok:Diggersby bibo:AudioDocument <sound/660-Diggersby.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/660.png> ;
#     pok:hasRegion pok:Kalos ;
#     pok:hasType pok:Ground,
#         pok:Normal ;
#     pok:stats <http://www.example.org/pokemon/423> ;
#     foaf:name "Diggersby" .
#
# pok:Diglett bibo:AudioDocument <sound/050-Diglett.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/50.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Ground ;
#     pok:stats <http://www.example.org/pokemon/265> ;
#     foaf:name "Diglett" .
#
# pok:Ditto bibo:AudioDocument <sound/132-Ditto.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/132.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Normal ;
#     pok:stats <http://www.example.org/pokemon/288> ;
#     foaf:name "Ditto" .
#
# pok:Dodrio bibo:AudioDocument <sound/085-Dodrio.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/85.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Flying,
#         pok:Normal ;
#     pok:stats <http://www.example.org/pokemon/460> ;
#     foaf:name "Dodrio" .
#
# pok:Doduo bibo:AudioDocument <sound/084-Doduo.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/84.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Flying,
#         pok:Normal ;
#     pok:stats <http://www.example.org/pokemon/310> ;
#     foaf:name "Doduo" .
#
# pok:Donphan bibo:AudioDocument <sound/232-Donphan.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/232.png> ;
#     pok:hasRegion pok:Johto ;
#     pok:hasType pok:Ground ;
#     pok:stats <http://www.example.org/pokemon/500> ;
#     foaf:name "Donphan" .
#
# pok:Doublade bibo:AudioDocument <sound/680-Doublade.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/680.png> ;
#     pok:hasRegion pok:Kalos ;
#     pok:hasType pok:Ghost,
#         pok:Steel ;
#     pok:stats <http://www.example.org/pokemon/448> ;
#     foaf:name "Doublade" .
#
# pok:Dragalge bibo:AudioDocument <sound/691-Dragalge.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/691.png> ;
#     pok:hasRegion pok:Kalos ;
#     pok:hasType pok:Dragon,
#         pok:Poison ;
#     pok:stats <http://www.example.org/pokemon/494> ;
#     foaf:name "Dragalge" .
#
# pok:Dragonair bibo:AudioDocument <sound/148-Dragonair.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/148.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Dragon ;
#     pok:stats <http://www.example.org/pokemon/420> ;
#     foaf:name "Dragonair" .
#
# pok:Dragonite bibo:AudioDocument <sound/149-Dragonite.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/149.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Dragon,
#         pok:Flying ;
#     pok:stats <http://www.example.org/pokemon/600> ;
#     foaf:name "Dragonite" .
#
# pok:Drapion bibo:AudioDocument <sound/452-Drapion.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/452.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Dark,
#         pok:Poison ;
#     pok:stats <http://www.example.org/pokemon/500> ;
#     foaf:name "Drapion" .
#
# pok:Dratini bibo:AudioDocument <sound/147-Dratini.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/147.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Dragon ;
#     pok:stats <http://www.example.org/pokemon/300> ;
#     foaf:name "Dratini" .
#
# pok:Drifblim bibo:AudioDocument <sound/426-Drifblim.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/426.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Flying,
#         pok:Ghost ;
#     pok:stats <http://www.example.org/pokemon/498> ;
#     foaf:name "Drifblim" .
#
# pok:Drifloon bibo:AudioDocument <sound/425-Drifloon.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/425.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Flying,
#         pok:Ghost ;
#     pok:stats <http://www.example.org/pokemon/348> ;
#     foaf:name "Drifloon" .
#
# pok:Drilbur bibo:AudioDocument <sound/529-Drilbur.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/529.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Ground ;
#     pok:stats <http://www.example.org/pokemon/328> ;
#     foaf:name "Drilbur" .
#
# pok:Drowzee bibo:AudioDocument <sound/096-Drowzee.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/96.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Psychic ;
#     pok:stats <http://www.example.org/pokemon/328> ;
#     foaf:name "Drowzee" .
#
# pok:Druddigon bibo:AudioDocument <sound/621-Druddigon.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/621.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Dragon ;
#     pok:stats <http://www.example.org/pokemon/485> ;
#     foaf:name "Druddigon" .
#
# pok:Ducklett bibo:AudioDocument <sound/580-Ducklett.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/580.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Flying,
#         pok:Water ;
#     pok:stats <http://www.example.org/pokemon/305> ;
#     foaf:name "Ducklett" .
#
# pok:Dugtrio bibo:AudioDocument <sound/051-Dugtrio.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/51.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Ground ;
#     pok:stats <http://www.example.org/pokemon/405> ;
#     foaf:name "Dugtrio" .
#
# pok:Dunsparce bibo:AudioDocument <sound/206-Dunsparce.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/206.png> ;
#     pok:hasRegion pok:Johto ;
#     pok:hasType pok:Normal ;
#     pok:stats <http://www.example.org/pokemon/415> ;
#     foaf:name "Dunsparce" .
#
# pok:Duosion bibo:AudioDocument <sound/578-Duosion.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/578.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Psychic ;
#     pok:stats <http://www.example.org/pokemon/370> ;
#     foaf:name "Duosion" .
#
# pok:Durant bibo:AudioDocument <sound/632-Durant.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/632.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Bug,
#         pok:Steel ;
#     pok:stats <http://www.example.org/pokemon/484> ;
#     foaf:name "Durant" .
#
# pok:Dusclops bibo:AudioDocument <sound/356-Dusclops.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/356.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Ghost ;
#     pok:stats <http://www.example.org/pokemon/455> ;
#     foaf:name "Dusclops" .
#
# pok:Dusknoir bibo:AudioDocument <sound/477-Dusknoir.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/477.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Ghost ;
#     pok:stats <http://www.example.org/pokemon/525> ;
#     foaf:name "Dusknoir" .
#
# pok:Duskull bibo:AudioDocument <sound/355-Duskull.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/355.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Ghost ;
#     pok:stats <http://www.example.org/pokemon/295> ;
#     foaf:name "Duskull" .
#
# pok:Dustox bibo:AudioDocument <sound/269-Dustox.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/269.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Bug,
#         pok:Poison ;
#     pok:stats <http://www.example.org/pokemon/385> ;
#     foaf:name "Dustox" .
#
# pok:Dwebble bibo:AudioDocument <sound/557-Dwebble.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/557.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Bug,
#         pok:Rock ;
#     pok:stats <http://www.example.org/pokemon/325> ;
#     foaf:name "Dwebble" .
#
# pok:Eelektrik bibo:AudioDocument <sound/603-Eelektrik.wav> ;
# ...
#     pok:stats <http://www.example.org/pokemon/240> ;
#     foaf:name "Whismur" .
#
# pok:Wigglytuff bibo:AudioDocument <sound/040-Wigglytuff.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/40.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Fairy,
#         pok:Normal ;
#     pok:stats <http://www.example.org/pokemon/435> ;
#     foaf:name "Wigglytuff" .
#
# pok:Wingull bibo:AudioDocument <sound/278-Wingull.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/278.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Flying,
#         pok:Water ;
#     pok:stats <http://www.example.org/pokemon/270> ;
#     foaf:name "Wingull" .
#
# pok:Wobbuffet bibo:AudioDocument <sound/202-Wobbuffet.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/202.png> ;
#     pok:hasRegion pok:Johto ;
#     pok:hasType pok:Psychic ;
#     pok:stats <http://www.example.org/pokemon/405> ;
#     foaf:name "Wobbuffet" .
#
# pok:Woobat bibo:AudioDocument <sound/527-Woobat.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/527.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Flying,
#         pok:Psychic ;
#     pok:stats <http://www.example.org/pokemon/313> ;
#     foaf:name "Woobat" .
#
# pok:Wooper bibo:AudioDocument <sound/194-Wooper.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/194.png> ;
#     pok:hasRegion pok:Johto ;
#     pok:hasType pok:Ground,
#         pok:Water ;
#     pok:stats <http://www.example.org/pokemon/210> ;
#     foaf:name "Wooper" .
#
# pok:Wormadam bibo:AudioDocument <sound/413-Wormadam.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/413.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Bug,
#         pok:Grass ;
#     pok:stats <http://www.example.org/pokemon/424> ;
#     foaf:name "Wormadam" .
#
# pok:Wurmple bibo:AudioDocument <sound/265-Wurmple.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/265.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Bug ;
#     pok:stats <http://www.example.org/pokemon/195> ;
#     foaf:name "Wurmple" .
#
# pok:Wynaut bibo:AudioDocument <sound/360-Wynaut.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/360.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Psychic ;
#     pok:stats <http://www.example.org/pokemon/260> ;
#     foaf:name "Wynaut" .
#
# pok:Xatu bibo:AudioDocument <sound/178-Xatu.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/178.png> ;
#     pok:hasRegion pok:Johto ;
#     pok:hasType pok:Flying,
#         pok:Psychic ;
#     pok:stats <http://www.example.org/pokemon/470> ;
#     foaf:name "Xatu" .
#
# pok:Xerneas bibo:AudioDocument <sound/716-Xerneas.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/716.png> ;
#     pok:hasRegion pok:Kalos ;
#     pok:hasType pok:Fairy ;
#     pok:stats <http://www.example.org/pokemon/680> ;
#     foaf:name "Xerneas" .
#
# pok:Yamask bibo:AudioDocument <sound/562-Yamask.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/562.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Ghost ;
#     pok:stats <http://www.example.org/pokemon/303> ;
#     foaf:name "Yamask" .
#
# pok:Yanma bibo:AudioDocument <sound/193-Yanma.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/193.png> ;
#     pok:hasRegion pok:Johto ;
#     pok:hasType pok:Bug,
#         pok:Flying ;
#     pok:stats <http://www.example.org/pokemon/390> ;
#     foaf:name "Yanma" .
#
# pok:Yanmega bibo:AudioDocument <sound/469-Yanmega.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/469.png> ;
#     pok:hasRegion pok:Sinnoh ;
#     pok:hasType pok:Bug,
#         pok:Flying ;
#     pok:stats <http://www.example.org/pokemon/515> ;
#     foaf:name "Yanmega" .
#
# pok:Yveltal bibo:AudioDocument <sound/717-Yveltal.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/717.png> ;
#     pok:hasRegion pok:Kalos ;
#     pok:hasType pok:Dark,
#         pok:Flying ;
#     pok:stats <http://www.example.org/pokemon/680> ;
#     foaf:name "Yveltal" .
#
# pok:Zangoose bibo:AudioDocument <sound/335-Zangoose.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/335.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Normal ;
#     pok:stats <http://www.example.org/pokemon/458> ;
#     foaf:name "Zangoose" .
#
# pok:Zapdos bibo:AudioDocument <sound/145-Zapdos.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/145.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Electric,
#         pok:Flying ;
#     pok:stats <http://www.example.org/pokemon/580> ;
#     foaf:name "Zapdos" .
#
# pok:Zebstrika bibo:AudioDocument <sound/523-Zebstrika.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/523.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Electric ;
#     pok:stats <http://www.example.org/pokemon/497> ;
#     foaf:name "Zebstrika" .
#
# pok:Zekrom bibo:AudioDocument <sound/644-Zekrom.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/644.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Dragon,
#         pok:Electric ;
#     pok:stats <http://www.example.org/pokemon/680> ;
#     foaf:name "Zekrom" .
#
# pok:Zigzagoon bibo:AudioDocument <sound/263-Zigzagoon.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/263.png> ;
#     pok:hasRegion pok:Hoenn ;
#     pok:hasType pok:Normal ;
#     pok:stats <http://www.example.org/pokemon/240> ;
#     foaf:name "Zigzagoon" .
#
# pok:Zoroark bibo:AudioDocument <sound/571-Zoroark.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/571.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Dark ;
#     pok:stats <http://www.example.org/pokemon/510> ;
#     foaf:name "Zoroark" .
#
# pok:Zorua bibo:AudioDocument <sound/570-Zorua.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/570.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Dark ;
#     pok:stats <http://www.example.org/pokemon/330> ;
#     foaf:name "Zorua" .
#
# pok:Zubat bibo:AudioDocument <sound/041-Zubat.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/41.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Flying,
#         pok:Poison ;
#     pok:stats <http://www.example.org/pokemon/245> ;
#     foaf:name "Zubat" .
#
# pok:Zweilous bibo:AudioDocument <sound/634-Zweilous.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/634.png> ;
#     pok:hasRegion pok:Unova ;
#     pok:hasType pok:Dark,
#         pok:Dragon ;
#     pok:stats <http://www.example.org/pokemon/420> ;
#     foaf:name "Zweilous" .
#
# pok:Zygarde bibo:AudioDocument <sound/718-Zygarde.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/718.png> ;
#     pok:hasRegion pok:Kalos ;
#     pok:hasType pok:Dragon,
#         pok:Ground ;
#     pok:stats <http://www.example.org/pokemon/600> ;
#     foaf:name "Zygarde" .
#
# pok:hasItem a owl:ObjectProperty ;
#     rdfs:range pok:Pokéball .
#
# pok:hasPokemon a owl:ObjectProperty ;
#     rdfs:domain pok:Trainer .
#
# pok:hasRegion a owl:ObjectProperty ;
#     rdfs:range pok:Region .
#
# pok:hasType a owl:ObjectProperty ;
#     rdfs:domain pok:Pokémon ;
#     rdfs:range pok:Typing .
#
# pok:stats a owl:ObjectProperty .
#
# foaf:name a owl:ObjectProperty .
#
# pok:Arcanine bibo:AudioDocument <sound/059-Arcanine.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/59.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Fire ;
#     pok:stats <http://www.example.org/pokemon/555> ;
#     foaf:name "Arcanine" .
#
# pok:Blastoise bibo:AudioDocument <sound/009-Blastoise.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/9.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Water ;
#     pok:stats <http://www.example.org/pokemon/530> ;
#     foaf:name "Blastoise" .
#
# pok:Charizard bibo:AudioDocument <sound/006-Charizard.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/6.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Fire,
#         pok:Flying ;
#     pok:stats <http://www.example.org/pokemon/534> ;
#     foaf:name "Charizard" .
#
# pok:Onix bibo:AudioDocument <sound/095-Onix.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/95.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Ground,
#         pok:Rock ;
#     pok:stats <http://www.example.org/pokemon/385> ;
#     foaf:name "Onix" .
#
# pok:Pikachu bibo:AudioDocument <sound/025-Pikachu.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/25.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Electric ;
#     pok:stats <http://www.example.org/pokemon/320> ;
#     foaf:name "Pikachu" .
#
# pok:Psyduck bibo:AudioDocument <sound/054-Psyduck.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/54.png> ;
#     pok:hasRegion pok:Kanto ;
#     pok:hasType pok:Water ;
#     pok:stats <http://www.example.org/pokemon/320> ;
#     foaf:name "Psyduck" .
#
# pok:Togepi bibo:AudioDocument <sound/175-Togepi.wav> ;
#     bibo:Image <https://pokeres.bastionbot.org/images/pokemon/175.png> ;
#     pok:hasRegion pok:Johto ;
#     pok:hasType pok:Fairy ;
#     pok:stats <http://www.example.org/pokemon/245> ;
#     foaf:name "Togepi" .
#
# pok:Ice pok:NeutralTo pok:Bug,
#         pok:Dark,
#         pok:Electric,
#         pok:Fairy,
#         pok:Fighting,
#         pok:Ghost,
#         pok:Normal,
#         pok:Poison,
#         pok:Psychic,
#         pok:Rock ;
#     pok:StrongTo pok:Dragon,
#         pok:Flying,
#         pok:Grass,
#         pok:Ground ;
#     pok:WeakTo pok:Fire,
#         pok:Ice,
#         pok:Steel,
#         pok:Water .
#
# pok:Fairy pok:NeutralTo pok:Bug,
#         pok:Electric,
#         pok:Fairy,
#         pok:Flying,
#         pok:Ghost,
#         pok:Grass,
#         pok:Ground,
#         pok:Ice,
#         pok:Normal,
#         pok:Psychic,
#         pok:Rock,
#         pok:Water ;
#     pok:StrongTo pok:Dark,
#         pok:Dragon,
#         pok:Fighting ;
#     pok:WeakTo pok:Fire,
#         pok:Poison,
#         pok:Steel .
#
# pok:Ghost pok:NeutralTo pok:Bug,
#         pok:Dragon,
#         pok:Electric,
#         pok:Fairy,
#         pok:Fighting,
#         pok:Fire,
#         pok:Flying,
#         pok:Grass,
#         pok:Ground,
#         pok:Ice,
#         pok:Poison,
#         pok:Rock,
#         pok:Steel,
#         pok:Water ;
#     pok:StrongTo pok:Ghost,
#         pok:Psychic ;
#     pok:WeakTo pok:Dark,
#         pok:Normal .
#
# pok:Dragon pok:NeutralTo pok:Bug,
#         pok:Dark,
#         pok:Electric,
#         pok:Fighting,
#         pok:Fire,
#         pok:Flying,
#         pok:Ghost,
#         pok:Grass,
#         pok:Ground,
#         pok:Ice,
#         pok:Normal,
#         pok:Poison,
#         pok:Psychic,
#         pok:Rock,
#         pok:Water ;
#     pok:StrongTo pok:Dragon ;
#     pok:WeakTo pok:Fairy,
#         pok:Steel .
#
# pok:Steel pok:NeutralTo pok:Bug,
#         pok:Dark,
#         pok:Dragon,
#         pok:Electric,
#         pok:Fighting,
#         pok:Flying,
#         pok:Ghost,
#         pok:Grass,
#         pok:Ground,
#         pok:Normal,
#         pok:Poison,
#         pok:Psychic ;
#     pok:StrongTo pok:Fairy,
#         pok:Ice,
#         pok:Rock ;
#     pok:WeakTo pok:Fire,
#         pok:Steel,
#         pok:Water .
#
# pok:Electric pok:NeutralTo pok:Bug,
#         pok:Dark,
#         pok:Fairy,
#         pok:Fighting,
#         pok:Fire,
#         pok:Ghost,
#         pok:Ice,
#         pok:Normal,
#         pok:Poison,
#         pok:Psychic,
#         pok:Rock,
#         pok:Steel ;
#     pok:StrongTo pok:Flying,
#         pok:Water ;
#     pok:WeakTo pok:Dragon,
#         pok:Electric,
#         pok:Grass,
#         pok:Ground .
#
# pok:Dark pok:NeutralTo pok:Bug,
#         pok:Dragon,
#         pok:Electric,
#         pok:Fire,
#         pok:Flying,
#         pok:Grass,
#         pok:Ground,
#         pok:Ice,
#         pok:Normal,
#         pok:Poison,
#         pok:Rock,
#         pok:Steel,
#         pok:Water ;
#     pok:StrongTo pok:Ghost,
#         pok:Psychic ;
#     pok:WeakTo pok:Dark,
#         pok:Fairy,
#         pok:Fighting .
#
# pok:Fighting pok:NeutralTo pok:Dragon,
#         pok:Electric,
#         pok:Fighting,
#         pok:Fire,
#         pok:Grass,
#         pok:Ground,
#         pok:Water ;
#     pok:StrongTo pok:Dark,
#         pok:Ice,
#         pok:Normal,
#         pok:Rock,
#         pok:Steel ;
#     pok:WeakTo pok:Bug,
#         pok:Fairy,
#         pok:Flying,
#         pok:Ghost,
#         pok:Poison,
#         pok:Psychic .
#
# pok:Rock pok:NeutralTo pok:Dark,
#         pok:Dragon,
#         pok:Electric,
#         pok:Fairy,
#         pok:Ghost,
#         pok:Grass,
#         pok:Normal,
#         pok:Poison,
#         pok:Psychic,
#         pok:Rock,
#         pok:Water ;
#     pok:StrongTo pok:Bug,
#         pok:Fire,
#         pok:Flying,
#         pok:Ice ;
#     pok:WeakTo pok:Fighting,
#         pok:Ground,
#         pok:Steel .
#
# pok:Fire pok:NeutralTo pok:Dark,
#         pok:Electric,
#         pok:Fairy,
#         pok:Fighting,
#         pok:Flying,
#         pok:Ghost,
#         pok:Ground,
#         pok:Normal,
#         pok:Poison,
#         pok:Psychic ;
#     pok:StrongTo pok:Bug,
#         pok:Grass,
#         pok:Ice,
#         pok:Steel ;
#     pok:WeakTo pok:Dragon,
#         pok:Fire,
#         pok:Rock,
#         pok:Water .
#
# pok:Poison pok:NeutralTo pok:Bug,
#         pok:Dark,
#         pok:Dragon,
#         pok:Electric,
#         pok:Fighting,
#         pok:Fire,
#         pok:Flying,
#         pok:Ice,
#         pok:Normal,
#         pok:Psychic,
#         pok:Water ;
#     pok:StrongTo pok:Fairy,
#         pok:Grass ;
#     pok:WeakTo pok:Ghost,
#         pok:Ground,
#         pok:Poison,
#         pok:Rock,
#         pok:Steel .
#
# pok:Ground pok:NeutralTo pok:Dark,
#         pok:Dragon,
#         pok:Fairy,
#         pok:Fighting,
#         pok:Ghost,
#         pok:Ground,
#         pok:Ice,
#         pok:Normal,
#         pok:Psychic,
#         pok:Water ;
#     pok:StrongTo pok:Electric,
#         pok:Fire,
#         pok:Poison,
#         pok:Rock,
#         pok:Steel ;
#     pok:WeakTo pok:Bug,
#         pok:Flying,
#         pok:Grass .
#
# pok:Bug pok:NeutralTo pok:Bug,
#         pok:Dragon,
#         pok:Electric,
#         pok:Ground,
#         pok:Ice,
#         pok:Normal,
#         pok:Rock,
#         pok:Water ;
#     pok:StrongTo pok:Dark,
#         pok:Grass,
#         pok:Psychic ;
#     pok:WeakTo pok:Fairy,
#         pok:Fighting,
#         pok:Fire,
#         pok:Flying,
#         pok:Ghost,
#         pok:Poison,
#         pok:Steel .
#
# pok:Psychic pok:NeutralTo pok:Bug,
#         pok:Dragon,
#         pok:Electric,
#         pok:Fairy,
#         pok:Fire,
#         pok:Flying,
#         pok:Ghost,
#         pok:Grass,
#         pok:Ground,
#         pok:Ice,
#         pok:Normal,
#         pok:Rock,
#         pok:Water ;
#     pok:StrongTo pok:Fighting,
#         pok:Poison ;
#     pok:WeakTo pok:Dark,
#         pok:Psychic,
#         pok:Steel .
#
# pok:Grass pok:NeutralTo pok:Dark,
#         pok:Electric,
#         pok:Fairy,
#         pok:Fighting,
#         pok:Ghost,
#         pok:Ice,
#         pok:Normal,
#         pok:Psychic ;
#     pok:StrongTo pok:Ground,
#         pok:Rock,
#         pok:Water ;
#     pok:WeakTo pok:Bug,
#         pok:Dragon,
#         pok:Fire,
#         pok:Flying,
#         pok:Grass,
#         pok:Poison,
#         pok:Steel .
#
# pok:Flying pok:NeutralTo pok:Dark,
#         pok:Dragon,
#         pok:Fairy,
#         pok:Fire,
#         pok:Flying,
#         pok:Ghost,
#         pok:Ground,
#         pok:Ice,
#         pok:Normal,
#         pok:Poison,
#         pok:Psychic,
#         pok:Water ;
#     pok:StrongTo pok:Bug,
#         pok:Fighting,
#         pok:Grass ;
#     pok:WeakTo pok:Electric,
#         pok:Rock,
#         pok:Steel .
#
# pok:Normal pok:NeutralTo pok:Bug,
#         pok:Dark,
#         pok:Dragon,
#         pok:Electric,
#         pok:Fairy,
#         pok:Fighting,
#         pok:Fire,
#         pok:Flying,
#         pok:Grass,
#         pok:Ground,
#         pok:Ice,
#         pok:Normal,
#         pok:Poison,
#         pok:Psychic,
#         pok:Water ;
#     pok:WeakTo pok:Ghost,
#         pok:Rock,
#         pok:Steel .
#
# pok:Water pok:NeutralTo pok:Bug,
#         pok:Dark,
#         pok:Electric,
#         pok:Fairy,
#         pok:Fighting,
#         pok:Flying,
#         pok:Ghost,
#         pok:Ice,
#         pok:Normal,
#         pok:Poison,
#         pok:Psychic,
#         pok:Steel ;
#     pok:StrongTo pok:Fire,
#         pok:Ground,
#         pok:Rock ;
#     pok:WeakTo pok:Dragon,
#         pok:Grass,
#         pok:Water .
